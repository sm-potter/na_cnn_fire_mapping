# %% [markdown]
# This script will read in the tif files and split into chunks of 128x128 for training the model.  Note I will ignore all chunks where there is no data for dNBR as we wouldn't want to train on this.
# The in path and outpath have to be where the files from the tif files were sent to from the google cloud storage bucket after downloading from earth engine.

# %% [markdown]
# Read in packages

# %%
import pandas as pd
import os
import numpy as np
import xarray as xr
import rioxarray
import glob
import random
import geopandas as gpd
from sklearn.utils import shuffle
from MightyMosaic import MightyMosaic

# %% [markdown]
# First take the input tif files and chunk them to sizes of 128x128 for the neural network.

# %%
"""arguments are path to .tif files to be chunked, out_path to save files, chunk size, and if desired a threshold"""       

#check if all 0
def is_matrix_all_zeros(matrix):
    # Convert the matrix to a NumPy array
    np_matrix = np.array(matrix)

    # Check if all elements in the array are zeros
    return np.all(np_matrix == 0)

#in_path to tif files
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85'
# in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_85'

#out_path which will be manipulated based on parameters below
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85'

# out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_85'

#right now everything is set to use 0 dnbr threshold
size = 128
threshold = True

if threshold == True:

    out_path = out_path + '_subs_0_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

if threshold == False:

    out_path = out_path + '_subs_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

files = os.listdir(in_path)

# files = ['median_6169.tif']

#loop through files
for f in files:

    if f.endswith('.tif'):
        
         
        #in file
        try:
        
            #file name
            f2 = f.replace('median_', '')

            #ID of file
            f_id = int(f2.replace('.tif', ''))
        
     

            #read in file
            in_mat = rioxarray.open_rasterio(os.path.join(in_path, f))

            
            #now turn in mat to numpy, and in mtbs to numpy
            in_mat = in_mat.to_numpy().astype(float)


            #convert to band last
            in_mat = np.moveaxis(in_mat, 0, 2) 
            
               
            #get dnbr
            t = in_mat[:, :, 0]
            
             #check if all 0
            result = is_matrix_all_zeros(t)
            
            #if it is not all 0s keep data
            if result == False:

                #mosaic
                mosaic = MightyMosaic.from_array(in_mat, (size,size), overlap_factor=1) 

                #take off last dimensions of mosaic which give edge effects as they are filled with no data
                mosaic = mosaic[:-1, :-1, :, :, :]


                #first two dimensions are number of chunks, 3 and 4 are size (256, 266) and last is nbands
                for i in range(mosaic.shape[0]):

                    for j in range(mosaic.shape[1]):

                        fname = os.path.join(str(i) + '_' +  str(j)+ '_' + f2.replace('.tif', '.npy'))
                        out_name = os.path.join(out_path, fname)

                        if os.path.exists(out_name) == False:

                            in_mat3 = mosaic[i, j, :, :, :-1]

                            target = mosaic[i, j, :, :, 3] #if only three predictors 3 is dnbr, otherwise it is 9

                            #turn nan to -999
                            in_mat[np.isnan(in_mat)] = -999

                            target = target.astype('int')

                            target[target <0 ] = 0
                            target[target >1 ] = 0

                            #
                            target[~np.isin(target, [0,1])] = 0

                            #turn nan to 0
                            target[np.isnan(target)] = 0

                            #if the target is all 0 don't train on it
                            # if np.all(target == 0) == False:

                            #now get dnbr which is the 6th band
                            dnbr = in_mat3[:, :, 0]
                            
                            result1 = is_matrix_all_zeros(dnbr)

                            if result1 == False:

                                #if threshold apply dnbr threshold
                                target[dnbr < 0] = 0

                                e = np.dstack([in_mat3, target])

                                np.save(out_name, e)

                                print(f)

        except:
            pass

# %% [markdown]
# Make faster with Dask

# %%
import os
import numpy as np
import rioxarray
import dask
from dask.diagnostics import ProgressBar
from MightyMosaic import MightyMosaic

# Check if all elements in a matrix are zero
def is_matrix_all_zeros(matrix):
    np_matrix = np.array(matrix)
    return np.all(np_matrix == 0)

# Input and output paths
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85'
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85'

size = 128
threshold = True

# Set output path based on threshold
if threshold:
    out_path += f'_subs_0_{size}'
else:
    out_path += f'_subs_{size}'

if not os.path.isdir(out_path):
    os.makedirs(out_path)

files = [f for f in os.listdir(in_path) if f.endswith('.tif')]

# Define the function to process a single file
def process_file(f):
    try:
        f2 = f.replace('median_', '')
        f_id = int(f2.replace('.tif', ''))
        in_mat = rioxarray.open_rasterio(os.path.join(in_path, f)).to_numpy().astype(float)
        in_mat = np.moveaxis(in_mat, 0, 2) 
        t = in_mat[:, :, 0]
        if not is_matrix_all_zeros(t):
            mosaic = MightyMosaic.from_array(in_mat, (size, size), overlap_factor=1) 
            mosaic = mosaic[:-1, :-1, :, :, :]
            for i in range(mosaic.shape[0]):
                for j in range(mosaic.shape[1]):
                    fname = os.path.join(str(i) + '_' +  str(j) + '_' + f2.replace('.tif', '.npy'))
                    out_name = os.path.join(out_path, fname)
                    if not os.path.exists(out_name):
                        in_mat3 = mosaic[i, j, :, :, :-1]
                        target = mosaic[i, j, :, :, 3]
                        in_mat3[np.isnan(in_mat3)] = -999
                        target = target.astype('int')
                        target[target < 0] = 0
                        target[target > 1] = 0
                        target[~np.isin(target, [0, 1])] = 0
                        target[np.isnan(target)] = 0
                        dnbr = in_mat3[:, :, 0]
                        if not is_matrix_all_zeros(dnbr):
                            if threshold:
                                target[dnbr < 0] = 0
                            e = np.dstack([in_mat3, target])
                            np.save(out_name, e)
                            print(f"Processed {f}")
    except Exception as e:
        print(f"Error processing {f}: {e}")

# Parallel execution using Dask
tasks = [dask.delayed(process_file)(f) for f in files]

with ProgressBar():
    dask.compute(*tasks)
# Out:
# [                                        ] | 0% Completed | 1.67 s msProcessed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# [                                        ] | 0% Completed | 1.77 sProcessed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# [                                        ] | 0% Completed | 1.87 sProcessed median_8566.tif
# Processed median_8566.tif
# Processed median_8566.tif
# [                                        ] | 0% Completed | 2.79 sProcessed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 2.89 sProcessed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 2.99 sProcessed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 3.09 sProcessed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 3.19 sProcessed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 3.29 sProcessed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 3.40 sProcessed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 3.50 sProcessed median_9188.tif
# Processed median_9543.tif
# Processed median_9188.tif
# Processed median_9188.tif
# Processed median_9543.tif
# Processed median_9188.tif
# [                                        ] | 0% Completed | 3.63 sProcessed median_9188.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9188.tif
# Processed median_9188.tif
# Processed median_9188.tif
# Processed median_9543.tif
# Processed median_9543.tif
# Processed median_9188.tif
# Processed median_9543.tif
# Processed median_9188.tif
# Processed median_9543.tif
# Processed median_9188.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 3.73 sProcessed median_9188.tif
# Processed median_9543.tif
# Processed median_9188.tif
# Processed median_9543.tif
# Processed median_9188.tif
# Processed median_9543.tif
# Processed median_9188.tif
# Processed median_9188.tif
# Processed median_9543.tif
# [                                        ] | 0% Completed | 4.35 sProcessed median_904.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 4.46 sProcessed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 4.56 sProcessed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 4.66 sProcessed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 4.76 sProcessed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 4.86 sProcessed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 4.96 sProcessed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_8879.tif
# [                                        ] | 0% Completed | 5.06 sProcessed median_904.tif
# Processed median_8879.tif
# Processed median_8879.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 5.26 sProcessed median_904.tif
# Processed median_8879.tif
# [                                        ] | 0% Completed | 5.39 sProcessed median_904.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_8879.tif
# [                                        ] | 0% Completed | 5.49 sProcessed median_904.tif
# Processed median_904.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_8879.tif
# [                                        ] | 0% Completed | 5.59 sProcessed median_904.tif
# Processed median_8879.tif
# Processed median_8879.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 5.69 sProcessed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# Processed median_904.tif
# [                                        ] | 0% Completed | 6.60 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 6.70 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 6.80 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 6.90 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.00 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.10 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.20 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.30 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.41 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.51 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.61 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_9321.tif
# Processed median_92.tif
# Processed median_9321.tif
# Processed median_92.tif
# Processed median_9321.tif
# Processed median_9086.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.71 sProcessed median_9321.tif
# Processed median_9086.tif
# Processed median_9321.tif
# Processed median_92.tif
# Processed median_9086.tif
# Processed median_9321.tif
# Processed median_92.tif
# Processed median_9086.tif
# Processed median_9321.tif
# Processed median_9086.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.81 sProcessed median_9086.tif
# Processed median_9321.tif
# Processed median_92.tif
# Processed median_9086.tif
# Processed median_9321.tif
# Processed median_9086.tif
# Processed median_9321.tif
# Processed median_9321.tif
# Processed median_92.tif
# Processed median_9086.tif
# Processed median_9321.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 7.91 sProcessed median_9321.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 8.02 sProcessed median_9321.tif
# Processed median_92.tif
# Processed median_9321.tif
# Processed median_92.tif
# Processed median_9321.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 8.12 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 8.22 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 8.32 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 8.43 sProcessed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# [                                        ] | 0% Completed | 8.53 sProcessed median_92.tif
# Processed median_8360.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 8.63 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 8.73 sProcessed median_8360.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8360.tif
# [                                        ] | 0% Completed | 8.83 sProcessed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_8360.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 8.94 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 9.04 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 9.15 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 9.25 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 9.35 sProcessed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 9.45 sProcessed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# [                                        ] | 0% Completed | 9.55 sProcessed median_92.tif
# Processed median_9138.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_9138.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_9138.tif
# [                                        ] | 0% Completed | 9.65 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 9.75 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 9.85 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 9.95 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.05 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.15 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.26 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.36 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.46 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.57 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.68 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.78 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.88 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 10.98 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 11.08 sProcessed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 11.18 sProcessed median_8446.tif
# Processed median_92.tifProcessed median_8446.tif
#
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# [                                        ] | 0% Completed | 11.31 sProcessed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 11.41 sProcessed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8446.tif
# [                                        ] | 0% Completed | 11.51 sProcessed median_92.tif
# Processed median_8446.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# [                                        ] | 0% Completed | 11.61 sProcessed median_92.tif
# Processed median_8446.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_8446.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 11.71 sProcessed median_8446.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# [                                        ] | 0% Completed | 11.81 sProcessed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 11.92 sProcessed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_8446.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 12.02 sProcessed median_92.tif
# Processed median_8446.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_92.tif
# Processed median_8681.tif
# Processed median_92.tif
# Processed median_8681.tif
# Processed median_92.tif
# [                                        ] | 0% Completed | 12.12 sProcessed median_8681.tif
# Processed median_92.tif
# Processed median_8681.tif
# Processed median_92.tif
# Processed median_8681.tif
# Processed median_92.tif
# Processed median_8681.tif
# Processed median_8681.tif
# Processed median_8681.tif
# [                                        ] | 0% Completed | 12.22 sProcessed median_8681.tif
# Processed median_8681.tif
# Processed median_8681.tif
# Processed median_8681.tif
# Processed median_8681.tif
# Processed median_8794.tif
# Processed median_8794.tif
# Processed median_8681.tif
# [                                        ] | 0% Completed | 12.32 sProcessed median_8794.tif
# Processed median_8681.tif
# Processed median_9579.tif
# Processed median_8794.tif
# Processed median_8681.tif
# Processed median_9579.tif
# Processed median_8794.tif
# Processed median_9579.tif
# Processed median_8794.tif
# Processed median_9579.tif
# Processed median_8794.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 12.42 sProcessed median_8794.tif
# Processed median_9579.tifProcessed median_8794.tif
#
# Processed median_8794.tif
# Processed median_8794.tif
# Processed median_8794.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 12.53 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 12.63 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 12.73 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 12.83 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 12.93 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.05 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.15 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9450.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.26 sProcessed median_9450.tif
# Processed median_9579.tif
# Processed median_9450.tif
# Processed median_9579.tif
# Processed median_9450.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.36 sProcessed median_9579.tif
# Processed median_9450.tif
# Processed median_9579.tif
# Processed median_9450.tif
# Processed median_9579.tif
# Processed median_9450.tif
# Processed median_9579.tif
# Processed median_9450.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.46 sProcessed median_9579.tif
# Processed median_9450.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.56 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.66 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.76 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.87 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 13.98 s
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 14.08 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 14.18 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 14.28 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 14.38 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 14.49 sProcessed median_9579.tif
# Processed median_9579.tif
# Processed median_9579.tif
# [                                        ] | 0% Completed | 14.80 sProcessed median_9092.tif
# Processed median_9092.tif
# [                                        ] | 0% Completed | 14.90 sProcessed median_9092.tif
# Processed median_9092.tif
# Processed median_9092.tif
# [                                        ] | 0% Completed | 15.02 sProcessed median_9092.tif
# Processed median_9486.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# [                                        ] | 0% Completed | 15.13 sProcessed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# [                                        ] | 0% Completed | 15.23 sProcessed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# [                                        ] | 0% Completed | 15.33 sProcessed median_9092.tif
# Processed median_9486.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9092.tif
# [                                        ] | 0% Completed | 15.43 sProcessed median_9486.tif
# Processed median_9092.tif
# Processed median_9486.tif
# Processed median_9486.tif
# Processed median_9486.tif
# Processed median_9486.tif
# [                                        ] | 0% Completed | 15.63 sProcessed median_9653.tif
# [                                        ] | 0% Completed | 15.74 sProcessed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# [                                        ] | 0% Completed | 15.84 sProcessed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# [                                        ] | 0% Completed | 15.94 sProcessed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# [                                        ] | 0% Completed | 16.04 sProcessed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# [                                        ] | 0% Completed | 16.15 sProcessed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# Processed median_9653.tif
# [                                        ] | 0% Completed | 16.35 sProcessed median_943.tif
# Processed median_943.tif
# Processed median_943.tif
# Processed median_943.tif
# Processed median_943.tif
# Processed median_943.tif
# [                                        ] | 0% Completed | 16.45 sProcessed median_943.tif
# Processed median_943.tif
# Processed median_943.tif
# Processed median_943.tif
# Processed median_943.tif
# Processed median_943.tif
# [                                        ] | 0% Completed | 16.55 sProcessed median_943.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_8897.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_8897.tif
# Processed median_943.tif
# Processed median_8897.tif
# Processed median_9310.tif
# [                                        ] | 0% Completed | 16.66 sProcessed median_943.tif
# Processed median_8897.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_8897.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_8897.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_8897.tif
# Processed median_943.tif
# [                                        ] | 0% Completed | 16.79 sProcessed median_8897.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_8897.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_8897.tif
# Processed median_943.tif
# Processed median_8897.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_9310.tif
# [                                        ] | 0% Completed | 16.89 sProcessed median_943.tif
# Processed median_8897.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_8897.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_8897.tif
# Processed median_943.tif
# Processed median_9310.tif
# [                                        ] | 0% Completed | 17.00 sProcessed median_8897.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_8897.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_943.tif
# [                                        ] | 0% Completed | 17.11 s
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_943.tif
# [                                        ] | 0% Completed | 17.21 sProcessed median_9310.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_943.tif
# Processed median_9310.tif
# Processed median_9310.tif
# [                                        ] | 0% Completed | 17.31 sProcessed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# [                                        ] | 0% Completed | 17.41 sProcessed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# [                                        ] | 0% Completed | 17.51 sProcessed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# [                                        ] | 0% Completed | 17.61 sProcessed median_9310.tif
# Processed median_9310.tif
# Processed median_9310.tif
# [                                        ] | 0% Completed | 17.71 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 17.82 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 17.92 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 18.02 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 18.12 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 18.22 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 18.33 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 18.43 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 18.53 sProcessed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 18.63 sProcessed median_901.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9499.tif
# Processed median_9562.tif
# Processed median_9499.tifProcessed median_901.tif
#
# [                                        ] | 0% Completed | 18.73 sProcessed median_9499.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9499.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9499.tif
# Processed median_8425.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9499.tif
# Processed median_8425.tif
# Processed median_9562.tif
# Processed median_901.tif
# [                                        ] | 0% Completed | 18.83 sProcessed median_9499.tif
#
# Processed median_901.tif
# Processed median_9562.tif
# Processed median_9499.tif
# Processed median_8425.tif
# Processed median_901.tif
# Processed median_8425.tifProcessed median_9499.tif
#
# Processed median_9562.tif
# Processed median_901.tif
# [                                        ] | 0% Completed | 18.94 sProcessed median_9562.tif
# Processed median_8425.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_8425.tif
# Processed median_9562.tif
# Processed median_8425.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_901.tif
# [                                        ] | 0% Completed | 19.04 sProcessed median_9798.tif
# Processed median_8425.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_8425.tif
# Processed median_901.tif
# Processed median_9562.tif
# Processed median_9798.tif
# Processed median_8425.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_8425.tif
# Processed median_9798.tif
# [                                        ] | 0% Completed | 19.14 sProcessed median_9562.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_8425.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_8425.tif
# Processed median_9798.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_8425.tif
# [                                        ] | 0% Completed | 19.24 sProcessed median_9798.tif
# Processed median_901.tif
# Processed median_9562.tif
# Processed median_8425.tif
# Processed median_9798.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_9562.tif
# Processed median_9798.tif
# Processed median_901.tif
# Processed median_9562.tif
# Processed median_9798.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9562.tif
# Processed median_9798.tif
# [                                        ] | 0% Completed | 19.34 sProcessed median_9798.tif
# Processed median_901.tif
# Processed median_9562.tif
# Processed median_9798.tif
# Processed median_901.tif
# Processed median_9562.tif
# Processed median_9798.tif
# Processed median_901.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 19.44 sProcessed median_9798.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_901.tif
# Processed median_9562.tif
# Processed median_9798.tif
# Processed median_9562.tif
# [                                        ] | 0% Completed | 19.54 sProcessed median_901.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_9562.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 19.65 sProcessed median_9798.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_901.tif
# Processed median_9798.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 19.75 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 19.85 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 19.95 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.06 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.16 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.27 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.37 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.48 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.58 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.69 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.79 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 20.89 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_8993.tif
# Processed median_901.tif
# Processed median_8993.tif
# Processed median_826.tif
# Processed median_901.tif
# Processed median_8993.tif
# [                                        ] | 1% Completed | 20.99 sProcessed median_901.tif
# Processed median_826.tif
# Processed median_8993.tif
# Processed median_901.tif
# Processed median_826.tif
# Processed median_8993.tif
# Processed median_901.tif
# Processed median_826.tif
# Processed median_8993.tif
# Processed median_901.tif
# Processed median_826.tif
# [                                        ] | 1% Completed | 21.10 sProcessed median_8993.tif
# Processed median_901.tif
# Processed median_826.tif
# Processed median_8993.tif
# Processed median_826.tif
# Processed median_901.tif
# Processed median_8993.tif
# Processed median_901.tif
# Processed median_8993.tif
# Processed median_826.tif
# [                                        ] | 1% Completed | 21.21 sProcessed median_901.tif
# Processed median_8993.tif
# Processed median_826.tif
# Processed median_901.tif
# Processed median_8993.tif
# Processed median_901.tif
# Processed median_8993.tif
# [                                        ] | 1% Completed | 21.31 sProcessed median_8993.tif
# Processed median_901.tif
# Processed median_8993.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_8993.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 21.41 sProcessed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# Processed median_901.tif
# [                                        ] | 1% Completed | 21.83 sProcessed median_9342.tif
# Processed median_9342.tif
# [                                        ] | 1% Completed | 21.93 sProcessed median_9342.tif
# Processed median_9342.tif
# Processed median_9342.tif
# [                                        ] | 1% Completed | 22.03 sProcessed median_9342.tif
# Processed median_9342.tif
# Processed median_9342.tif
# Processed median_9342.tif
# [                                        ] | 1% Completed | 22.13 sError processing median_670.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [                                        ] | 1% Completed | 23.24 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 23.35 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_9029.tif
# [                                        ] | 1% Completed | 23.45 sProcessed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# [                                        ] | 1% Completed | 23.55 sProcessed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 23.65 sProcessed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# Processed median_9029.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 23.75 sProcessed median_9029.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 23.85 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 23.96 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.06 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.16 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.26 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.37 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.47 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.57 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.67 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.77 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.88 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 24.98 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 25.08 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# [                                        ] | 1% Completed | 25.18 sProcessed median_8975.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_8975.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_8975.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8975.tif
# Processed median_9237.tif
# Processed median_8975.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 25.28 sProcessed median_9237.tif
# Processed median_8975.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8975.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_8975.tif
# Processed median_9237.tif
# [                                        ] | 1% Completed | 25.38 sProcessed median_8975.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# [                                        ] | 1% Completed | 25.49 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Error processing median_8785.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [                                        ] | 1% Completed | 25.59 sProcessed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 25.70 sProcessed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 25.80 sProcessed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8683.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8683.tif
# [                                        ] | 1% Completed | 25.90 sProcessed median_8480.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8683.tif
# Processed median_8480.tif
# Processed median_9237.tif
# Processed median_8683.tif
# Processed median_8364.tif
# Processed median_9237.tif
# Processed median_8480.tif
# [                                        ] | 1% Completed | 26.01 sProcessed median_8364.tif
# Processed median_8683.tif
# Processed median_9237.tif
# Processed median_8683.tif
# Processed median_8364.tif
# Processed median_9237.tif
# Processed median_8683.tif
# Processed median_8364.tif
# Processed median_9237.tif
# Processed median_8364.tif
# [                                        ] | 1% Completed | 26.11 sProcessed median_8683.tif
# Processed median_9237.tif
# Processed median_8683.tif
# Processed median_8364.tif
# Processed median_9237.tif
# Processed median_8683.tif
# Processed median_9237.tif
# Processed median_8364.tif
# [                                        ] | 1% Completed | 26.21 sProcessed median_8683.tif
# Processed median_9237.tif
# Processed median_8364.tif
# Processed median_8683.tif
# Processed median_9237.tif
# ...
# Processed median_9202.tif
# Processed median_9202.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# [######                                  ] | 15% Completed | 276.15 sProcessed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# [######                                  ] | 15% Completed | 276.25 sProcessed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# [######                                  ] | 15% Completed | 276.36 sProcessed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# Processed median_9969.tif
# [######                                  ] | 15% Completed | 276.96 sProcessed median_8639.tif
# Processed median_8639.tif
# [######                                  ] | 15% Completed | 277.06 sProcessed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# [######                                  ] | 15% Completed | 277.17 sProcessed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# [######                                  ] | 15% Completed | 277.27 sProcessed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# [######                                  ] | 15% Completed | 277.38 sProcessed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# Processed median_8639.tif
# [######                                  ] | 15% Completed | 277.48 sProcessed median_8639.tif
# Processed median_829.tif
# Processed median_829.tif
# [######                                  ] | 15% Completed | 277.58 sProcessed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# [######                                  ] | 15% Completed | 277.68 s
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# [######                                  ] | 15% Completed | 277.79 sProcessed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# [######                                  ] | 15% Completed | 277.89 sProcessed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# Processed median_829.tif
# [######                                  ] | 15% Completed | 278.60 sError processing median_1585.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [######                                  ] | 15% Completed | 278.80 sProcessed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# [######                                  ] | 15% Completed | 278.91 sProcessed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# [######                                  ] | 15% Completed | 279.01 sProcessed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# Processed median_8972.tif
# Processed median_9782.tif
# Processed median_8972.tif
# Processed median_9782.tif
# [######                                  ] | 15% Completed | 279.11 sProcessed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# [######                                  ] | 15% Completed | 279.21 sProcessed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# [######                                  ] | 15% Completed | 279.32 sProcessed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# Processed median_9782.tif
# [######                                  ] | 15% Completed | 279.42 sProcessed median_9782.tif
# Processed median_9782.tif
# [######                                  ] | 15% Completed | 279.84 sProcessed median_9848.tif
# Processed median_9848.tif
# [######                                  ] | 15% Completed | 279.95 sProcessed median_9848.tif
# Processed median_8407.tif
# Processed median_9848.tif
# Processed median_8407.tif
# Processed median_9848.tif
# Processed median_8407.tif
# Processed median_9848.tif
# Processed median_8407.tif
# Processed median_9848.tif
# Processed median_8407.tif
# Processed median_9848.tif
# [######                                  ] | 15% Completed | 280.05 sProcessed median_8407.tif
# Processed median_9848.tif
# Processed median_8407.tif
# Processed median_8407.tif
# Processed median_8407.tif
# [######                                  ] | 15% Completed | 282.92 sProcessed median_9889.tif
# Processed median_9889.tif
# Processed median_9889.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9983.tif
# [######                                  ] | 15% Completed | 283.02 sProcessed median_9889.tif
# Processed median_9983.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9983.tif
# [######                                  ] | 15% Completed | 283.12 sProcessed median_9889.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9983.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9889.tif
# [######                                  ] | 15% Completed | 283.22 sProcessed median_9983.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9889.tif
# [######                                  ] | 15% Completed | 283.32 sProcessed median_9983.tif
# Processed median_9181.tif
# [######                                  ] | 15% Completed | 283.54 sProcessed median_9889.tif
# Processed median_9983.tif
# Processed median_9181.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9181.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9889.tif
# [######                                  ] | 15% Completed | 283.65 sProcessed median_9181.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9983.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9889.tif
# [######                                  ] | 15% Completed | 283.76 sProcessed median_9983.tif
# Processed median_9181.tif
# Processed median_9889.tif
# Processed median_9983.tif
# Processed median_9181.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9889.tif
# Processed median_9181.tif
# Processed median_9889.tif
# [######                                  ] | 15% Completed | 283.86 sProcessed median_9181.tif
# Processed median_9889.tif
# Processed median_9889.tif
# Processed median_9889.tif
# [######                                  ] | 15% Completed | 286.09 sProcessed median_8216.tif
# [######                                  ] | 15% Completed | 286.20 sProcessed median_8216.tif
# Processed median_8216.tif
# Processed median_8216.tif
# Processed median_8216.tif
# Processed median_8216.tif
# Processed median_8216.tif
# Processed median_8216.tif
# [######                                  ] | 15% Completed | 286.30 sProcessed median_8216.tif
# [######                                  ] | 15% Completed | 286.91 sProcessed median_9946.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9827.tif
# [######                                  ] | 15% Completed | 287.01 sProcessed median_9946.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9827.tif
# [######                                  ] | 15% Completed | 287.12 sProcessed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9827.tif
# Processed median_9946.tif
# Processed median_9946.tif
# Processed median_9827.tif
# [######                                  ] | 15% Completed | 287.22 sProcessed median_9946.tif
# Processed median_8731.tif
# Processed median_9946.tif
# Processed median_9946.tif
# Processed median_8731.tif
# Processed median_9663.tif
# Processed median_9946.tif
# Processed median_8731.tif
# Processed median_9946.tif
# Processed median_8731.tif
# Processed median_8731.tif
# Processed median_9663.tif
# Processed median_9946.tif
# [######                                  ] | 15% Completed | 287.32 sProcessed median_8731.tif
# Processed median_8731.tif
# Processed median_9663.tif
# Processed median_8731.tif
# Processed median_8731.tif
# Processed median_9663.tif
# Processed median_8731.tif
# Processed median_9663.tif
# Processed median_8731.tif
# Processed median_8731.tif
# Processed median_9663.tif
# [######                                  ] | 15% Completed | 287.43 sProcessed median_9663.tif
# Processed median_8731.tif
# Processed median_9663.tif
# Processed median_8731.tif
# Processed median_9786.tif
# Processed median_9663.tif
# Processed median_8731.tif
# Processed median_9786.tif
# Processed median_8731.tif
# Processed median_9786.tif
# Processed median_9663.tif
# Processed median_9663.tif
# Processed median_9976.tif
# Processed median_9786.tif
# Processed median_9663.tif
# Processed median_9976.tif
# Processed median_9786.tif
# [######                                  ] | 15% Completed | 287.53 sProcessed median_9976.tif
# Processed median_9786.tif
# Processed median_9663.tif
# Processed median_9976.tif
# Processed median_9786.tif
# Processed median_9663.tif
# Processed median_9976.tif
# Processed median_9786.tif
# Processed median_9663.tif
# Processed median_9976.tif
# Processed median_9663.tif
# Processed median_9976.tif
# Processed median_9786.tif
# Processed median_9786.tif
# Processed median_9976.tif
# Processed median_9786.tif
# [######                                  ] | 15% Completed | 287.63 sProcessed median_9976.tif
# Processed median_9786.tif
# Processed median_9976.tif
# Processed median_9976.tif
# Processed median_9976.tif
# Processed median_9976.tif
# [######                                  ] | 15% Completed | 287.74 sProcessed median_9976.tif
# Processed median_9976.tif
# Processed median_9976.tif
# [######                                  ] | 15% Completed | 287.95 sProcessed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# [######                                  ] | 15% Completed | 288.06 sProcessed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# [######                                  ] | 15% Completed | 288.16 sProcessed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# [######                                  ] | 15% Completed | 288.29 sProcessed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9841.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 288.39 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 288.49 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 288.59 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 288.69 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 288.79 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 288.89 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 288.99 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 289.09 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 289.20 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 289.30 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 289.40 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 289.50 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 289.60 sProcessed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# Processed median_9516.tif
# [######                                  ] | 15% Completed | 289.70 s

# %%
't'
# Out:
# 't'

# %% [markdown]
# Now take those files and save a csv with file names for the 80/10/10 training, validation, testing parts

# %%
def listdir_fullpath(d):
    return [os.path.join(d, f) for f in os.listdir(d)]

#list of files
# file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_1985_sent_harm_subs_128')
file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85_subs_0_128')


#shuffle file_names
file_names = shuffle(file_names, random_state = 555)


print(len(file_names))

random.seed(555)
# #get train at 80%

train_files = random.sample(file_names, k=round(len(file_names) * 0.8))

#files at 10%
val_files = list(set(file_names) - set(train_files))
val_files = random.sample(val_files, k=round(len(file_names) * 0.1))

#combine traini and val
temp = train_files + val_files
#get test files at 10%
test_files = list(set(file_names) - set(temp))


#convert the lists to pandas dataframes
train = pd.DataFrame({'Files': train_files})
val = pd.DataFrame({'Files': val_files})
test = pd.DataFrame({'Files': test_files})

print(train.shape)
print(val.shape)
print(test.shape)

train.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85_training_files.csv')
val.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85_validation_files.csv')
test.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85_testing_files.csv')
# Out:
# 649494
# (519595, 1)
# (64949, 1)
# (64950, 1)

# %%
import rioxarray 
import xarray as xr

rds = rioxarray.open_rasterio('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85/median_8.tif')
# Print the band names
print(f"Band names: {rds.band.values}")
# Out:
# Band names: [1 2 3 4]

# %%
rds
# Out:
# <xarray.DataArray (band: 4, y: 1912, x: 1975)>
# [15104800 values with dtype=int16]
# Coordinates:
#   * band         (band) int64 1 2 3 4
#   * x            (x) float64 -3.436e+06 -3.436e+06 ... -3.377e+06 -3.377e+06
#   * y            (y) float64 -2.716e+06 -2.716e+06 ... -2.774e+06 -2.774e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('NBR_p85', 'NDVI_p85', 'NDII_p85', 'y')

# %%
library(terra)


rds = rast('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_85/median_8.tif')

names(rds)
# Out:
# terra 1.7.71
# [1] "NBR_p85"  "NDVI_p85" "NDII_p85" "y"
