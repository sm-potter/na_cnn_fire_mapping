# %% [markdown]
# This script will read in the tif files and split into chunks of 128x128 for training the model.  Note I will ignore all chunks where there is no data for dNBR as we wouldn't want to train on this.
# The in path and outpath have to be where the files from the tif files were sent to from the google cloud storage bucket after downloading from earth engine.

# %% [markdown]
# Read in packages

# %%
import pandas as pd
import os
import numpy as np
import xarray as xr
import rioxarray
import glob
import random
import geopandas as gpd
from sklearn.utils import shuffle
from MightyMosaic import MightyMosaic

# %% [markdown]
# Right now the files are called  median_i.tif.tif, make median_i.tif

# %%
import os
import re

# Define the input path
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old'

# List all files in the directory
files = os.listdir(in_path)

# Loop through the files
for file_name in files:
    if file_name.endswith('.tif.tif'):
        # Extract the number i using regex
        match = re.search(r'\d+', file_name)
        if match:
            number = match.group(0)
            # Create the new file name
            new_name = f'median_{number}.tif'
            # Get the full paths
            old_file = os.path.join(in_path, file_name)
            new_file = os.path.join(in_path, new_name)
            # Rename the file
            # os.rename(old_file, new_file)
            print(f'Renamed: {old_file} -> {new_file}')

# %% [markdown]
# First take the input tif files and chunk them to sizes of 128x128 for the neural network.

# %%
"""arguments are path to .tif files to be chunked, out_path to save files, chunk size, and if desired a threshold"""       

#check if all 0
def is_matrix_all_zeros(matrix):
    # Convert the matrix to a NumPy array
    np_matrix = np.array(matrix)

    # Check if all elements in the array are zeros
    return np.all(np_matrix == 0)

#in_path to tif files
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old'

#out_path which will be manipulated based on parameters below
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old'


#right now everything is set to use 0 dnbr threshold
size = 128
threshold = True

if threshold == True:

    out_path = out_path + '_subs_0_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

if threshold == False:

    out_path = out_path + '_subs_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

files = os.listdir(in_path)

# files = ['median_6169.tif']

#loop through files
for f in files:

    if f.endswith('.tif'):
        
         
        #in file
        try:
        
            #file name
            f2 = f.replace('median_', '')

            #ID of file
            f_id = int(f2.replace('.tif', ''))
        
     

            #read in file
            in_mat = rioxarray.open_rasterio(os.path.join(in_path, f))

            
            #now turn in mat to numpy, and in mtbs to numpy
            in_mat = in_mat.to_numpy().astype(float)


            #convert to band last
            in_mat = np.moveaxis(in_mat, 0, 2) 
            
               
            #get dnbr
            t = in_mat[:, :, 0]
            
             #check if all 0
            result = is_matrix_all_zeros(t)
            
            #if it is not all 0s keep data
            if result == False:

                #mosaic
                mosaic = MightyMosaic.from_array(in_mat, (size,size), overlap_factor=1) 

                #take off last dimensions of mosaic which give edge effects as they are filled with no data
                mosaic = mosaic[:-1, :-1, :, :, :]


                #first two dimensions are number of chunks, 3 and 4 are size (256, 266) and last is nbands
                for i in range(mosaic.shape[0]):

                    for j in range(mosaic.shape[1]):

                        fname = os.path.join(str(i) + '_' +  str(j)+ '_' + f2.replace('.tif', '.npy'))
                        out_name = os.path.join(out_path, fname)

                        if os.path.exists(out_name) == False:

                            in_mat3 = mosaic[i, j, :, :, :-1]

                            target = mosaic[i, j, :, :, 3]

                            #turn nan to -999
                            in_mat[np.isnan(in_mat)] = -999

                            target = target.astype('int')

                            target[target <0 ] = 0
                            target[target >1 ] = 0

                            #
                            target[~np.isin(target, [0,1])] = 0

                            #turn nan to 0
                            target[np.isnan(target)] = 0

                            #if the target is all 0 don't train on it
                            # if np.all(target == 0) == False:

                            #now get dnbr which is the 6th band
                            dnbr = in_mat3[:, :, 0]
                            
                            result1 = is_matrix_all_zeros(dnbr)

                            if result1 == False:

                                #if threshold apply dnbr threshold
                                target[dnbr < 0] = 0

                                e = np.dstack([in_mat3, target])

                                np.save(out_name, e)

                                print(f)

        except:
            pass

# %% [markdown]
# Faster with dask

# %%
import os
import numpy as np
import rioxarray
import dask
from dask.diagnostics import ProgressBar
from MightyMosaic import MightyMosaic

# Check if all elements in a matrix are zero
def is_matrix_all_zeros(matrix):
    np_matrix = np.array(matrix)
    return np.all(np_matrix == 0)

# Input and output paths
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old'
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old'
size = 128
threshold = True

# Set output path based on threshold
if threshold:
    out_path += f'_subs_0_{size}'
else:
    out_path += f'_subs_{size}'

if not os.path.isdir(out_path):
    os.makedirs(out_path)

files = [f for f in os.listdir(in_path) if f.endswith('.tif')]

# Define the function to process a single file
def process_file(f):
    try:
        f2 = f.replace('median_', '')
        f_id = int(f2.replace('.tif', ''))
        in_mat = rioxarray.open_rasterio(os.path.join(in_path, f)).to_numpy().astype(float)
        in_mat = np.moveaxis(in_mat, 0, 2) 
        t = in_mat[:, :, 0]
        if not is_matrix_all_zeros(t):
            mosaic = MightyMosaic.from_array(in_mat, (size, size), overlap_factor=1) 
            mosaic = mosaic[:-1, :-1, :, :, :]
            for i in range(mosaic.shape[0]):
                for j in range(mosaic.shape[1]):
                    fname = os.path.join(str(i) + '_' +  str(j) + '_' + f2.replace('.tif', '.npy'))
                    out_name = os.path.join(out_path, fname)
                    if not os.path.exists(out_name):
                        in_mat3 = mosaic[i, j, :, :, :-1]
                        target = mosaic[i, j, :, :, 3]
                        in_mat3[np.isnan(in_mat3)] = -999
                        target = target.astype('int')
                        target[target < 0] = 0
                        target[target > 1] = 0
                        target[~np.isin(target, [0, 1])] = 0
                        target[np.isnan(target)] = 0
                        dnbr = in_mat3[:, :, 0]
                        if not is_matrix_all_zeros(dnbr):
                            if threshold:
                                target[dnbr < 0] = 0
                            e = np.dstack([in_mat3, target])
                            np.save(out_name, e)
                            print(f"Processed {f}")
    except Exception as e:
        print(f"Error processing {f}: {e}")

# Parallel execution using Dask
tasks = [dask.delayed(process_file)(f) for f in files]

with ProgressBar():
    dask.compute(*tasks)
# Out:
# [                                        ] | 0% Completed | 6.46 s msProcessed median_9386.tif
# Processed median_9386.tif
# [                                        ] | 0% Completed | 14.89 sError processing median_1416.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [                                        ] | 0% Completed | 15.22 sError processing median_6716.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [                                        ] | 1% Completed | 19.92 sError processing median_3663.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [                                        ] | 1% Completed | 27.71 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 27.82 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 27.92 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 28.03 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 28.13 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 28.23 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 28.33 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 28.45 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 28.55 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 28.67 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 28.77 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 28.88 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 28.98 s
# Processed median_8584.tif
# [                                        ] | 1% Completed | 29.08 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 29.18 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 29.29 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 29.39 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 29.49 s
# Processed median_8584.tif
# [                                        ] | 1% Completed | 29.59 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 29.69 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 29.80 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 29.90 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 30.01 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 30.11 sProcessed median_8584.tif
# Error processing median_5549.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# Processed median_8584.tif
# [                                        ] | 1% Completed | 30.21 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 30.31 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 30.41 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 30.51 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 30.63 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 30.74 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 30.84 sProcessed median_8584.tif
# [                                        ] | 1% Completed | 30.95 sProcessed median_8584.tif
# Processed median_8584.tif
# [                                        ] | 1% Completed | 31.06 sProcessed median_8584.tif
# [                                        ] | 2% Completed | 35.96 sError processing median_5719.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [#                                       ] | 2% Completed | 49.89 sError processing median_6272.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [#                                       ] | 3% Completed | 63.12 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 63.22 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 63.32 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 63.42 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 63.52 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 63.63 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 63.73 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 63.83 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 63.93 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 64.03 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 64.13 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 64.24 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 64.36 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 64.47 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 64.58 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 64.70 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 64.80 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 64.92 sProcessed median_720.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 65.02 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 65.12 sProcessed median_7779.tif
# Processed median_720.tif
# [#                                       ] | 3% Completed | 65.29 sProcessed median_720.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 65.39 sProcessed median_7779.tif
# Processed median_720.tif
# [#                                       ] | 3% Completed | 65.51 sProcessed median_7779.tif
# Processed median_720.tif
# [#                                       ] | 3% Completed | 65.61 sProcessed median_7779.tif
# Processed median_7779.tif
# Processed median_720.tif
# [#                                       ] | 3% Completed | 65.75 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 66.10 sProcessed median_7779.tif
# Processed median_720.tif
# [#                                       ] | 3% Completed | 66.21 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 66.34 sProcessed median_7779.tif
# Processed median_720.tif
# [#                                       ] | 3% Completed | 66.45 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 66.58 sProcessed median_7779.tif
# Processed median_720.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 66.79 sProcessed median_720.tif
# Processed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 67.00 sProcessed median_720.tif
# Processed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 67.12 sProcessed median_7779.tif
# Processed median_720.tif
# [#                                       ] | 3% Completed | 67.27 sProcessed median_7779.tif
# Processed median_720.tif
# [#                                       ] | 3% Completed | 67.39 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 67.52 sProcessed median_720.tif
# Processed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 67.67 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 67.78 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 67.90 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 68.02 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 68.15 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 68.26 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 68.36 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 68.46 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 68.59 sProcessed median_7779.tif
# [#                                       ] | 3% Completed | 68.70 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 3% Completed | 68.85 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 4% Completed | 68.97 sProcessed median_7779.tif
# [#                                       ] | 4% Completed | 69.07 sProcessed median_7779.tif
# [#                                       ] | 4% Completed | 69.17 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 4% Completed | 69.27 sProcessed median_7779.tif
# [#                                       ] | 4% Completed | 69.38 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 4% Completed | 69.49 sProcessed median_7779.tif
# [#                                       ] | 4% Completed | 69.60 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 4% Completed | 69.71 sProcessed median_7779.tif
# [#                                       ] | 4% Completed | 69.81 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 4% Completed | 69.91 sProcessed median_7779.tif
# [#                                       ] | 4% Completed | 70.01 sProcessed median_7779.tif
# [#                                       ] | 4% Completed | 70.11 sProcessed median_7779.tif
# Processed median_7779.tif
# [#                                       ] | 4% Completed | 82.03 sError processing median_10154.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [#                                       ] | 4% Completed | 83.90 sError processing median_4760.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [##                                      ] | 5% Completed | 88.05 sError processing median_5978.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [##                                      ] | 5% Completed | 90.13 sProcessed median_9848.tif
# Processed median_9848.tif
# [##                                      ] | 5% Completed | 90.23 sProcessed median_9848.tif
# [##                                      ] | 5% Completed | 90.35 sProcessed median_9848.tif
# [##                                      ] | 5% Completed | 90.45 sProcessed median_9848.tif
# [##                                      ] | 5% Completed | 90.55 sProcessed median_9848.tif
# [##                                      ] | 5% Completed | 90.65 sProcessed median_9848.tif
# Processed median_9848.tif
# [##                                      ] | 5% Completed | 90.76 sProcessed median_9848.tif
# [##                                      ] | 5% Completed | 93.59 sError processing median_7115.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [##                                      ] | 6% Completed | 105.96 sError processing median_8730.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [##                                      ] | 6% Completed | 111.69 sProcessed median_9095.tif
# Processed median_9095.tif
# [##                                      ] | 6% Completed | 111.80 sProcessed median_9095.tif
# [##                                      ] | 6% Completed | 111.91 sProcessed median_9095.tif
# [##                                      ] | 6% Completed | 112.37 sError processing median_9126.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [##                                      ] | 7% Completed | 113.92 sProcessed median_6201.tif
# Processed median_6201.tif
# [##                                      ] | 7% Completed | 114.02 sProcessed median_6201.tif
# Error processing median_10349.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [##                                      ] | 7% Completed | 114.12 sProcessed median_6201.tif
# [##                                      ] | 7% Completed | 114.23 sProcessed median_6201.tif
# Processed median_6201.tif
# [##                                      ] | 7% Completed | 114.35 sProcessed median_6201.tif
# [##                                      ] | 7% Completed | 114.45 sProcessed median_6201.tif
# [##                                      ] | 7% Completed | 114.55 sProcessed median_6201.tif
# [##                                      ] | 7% Completed | 115.16 sError processing median_4703.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [##                                      ] | 7% Completed | 118.73 sProcessed median_481.tif
# [##                                      ] | 7% Completed | 118.84 sProcessed median_481.tif
# Processed median_481.tif
# [##                                      ] | 7% Completed | 118.98 sProcessed median_481.tif
# [##                                      ] | 7% Completed | 119.10 sProcessed median_481.tif
# Processed median_481.tif
# [##                                      ] | 7% Completed | 119.21 sProcessed median_481.tif
# [##                                      ] | 7% Completed | 119.33 sProcessed median_481.tif
# Processed median_481.tif
# [##                                      ] | 7% Completed | 119.55 sProcessed median_481.tif
# [##                                      ] | 7% Completed | 119.67 sProcessed median_481.tif
# Processed median_481.tif
# [###                                     ] | 7% Completed | 119.78 sProcessed median_481.tif
# [###                                     ] | 7% Completed | 119.91 sProcessed median_481.tif
# Processed median_481.tif
# [###                                     ] | 7% Completed | 120.01 sProcessed median_481.tif
# [###                                     ] | 7% Completed | 120.11 sProcessed median_481.tif
# [###                                     ] | 7% Completed | 120.21 sProcessed median_481.tif
# [###                                     ] | 7% Completed | 120.31 sProcessed median_481.tif
# [###                                     ] | 7% Completed | 120.42 sProcessed median_481.tif
# [###                                     ] | 7% Completed | 120.52 sProcessed median_481.tif
# [###                                     ] | 7% Completed | 120.62 sProcessed median_481.tif
# [###                                     ] | 8% Completed | 129.56 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 129.66 sProcessed median_6946.tif
# Processed median_6946.tif
# [###                                     ] | 8% Completed | 129.76 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 129.86 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 129.96 sProcessed median_6946.tif
# Processed median_6946.tif
# [###                                     ] | 8% Completed | 130.07 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 130.17 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 130.27 sProcessed median_6946.tif
# Processed median_6946.tif
# [###                                     ] | 8% Completed | 130.37 sProcessed median_6946.tif
# Error processing median_10939.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [###                                     ] | 8% Completed | 130.47 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 130.58 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 130.69 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 130.80 sProcessed median_6946.tif
# [###                                     ] | 8% Completed | 141.12 sError processing median_1289.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [###                                     ] | 9% Completed | 143.36 sError processing median_4765.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [###                                     ] | 9% Completed | 145.26 sProcessed median_1110.tif
# [###                                     ] | 9% Completed | 145.36 sProcessed median_1110.tif
# [###                                     ] | 9% Completed | 145.47 sProcessed median_1110.tif
# [###                                     ] | 9% Completed | 145.57 sProcessed median_1110.tif
# [###                                     ] | 9% Completed | 153.60 sError processing median_10955.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [###                                     ] | 9% Completed | 155.42 sProcessed median_1588.tif
# Processed median_1588.tif
# [###                                     ] | 9% Completed | 155.52 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 155.62 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 155.72 sProcessed median_1588.tif
# Processed median_1588.tif
# [###                                     ] | 9% Completed | 155.83 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 155.95 sProcessed median_1588.tif
# Processed median_1588.tif
# [###                                     ] | 9% Completed | 156.06 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 156.16 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 156.27 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 156.39 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 156.49 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 156.60 sProcessed median_1588.tif
# [###                                     ] | 9% Completed | 158.22 sError processing median_7781.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [####                                    ] | 10% Completed | 161.98 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 162.09 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 162.20 sProcessed median_10540.tif
# Processed median_10540.tif
# [####                                    ] | 10% Completed | 162.30 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 162.40 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 162.50 sProcessed median_10540.tif
# Processed median_10540.tif
# [####                                    ] | 10% Completed | 162.60 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 162.71 sProcessed median_10540.tif
# Processed median_10540.tif
# [####                                    ] | 10% Completed | 162.81 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 162.93 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 163.04 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 163.15 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 163.26 sProcessed median_10540.tif
# Processed median_10540.tif
# [####                                    ] | 10% Completed | 163.36 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 163.49 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 163.60 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 163.71 sProcessed median_10540.tif
# Processed median_10540.tif
# [####                                    ] | 10% Completed | 163.82 sProcessed median_10540.tif
# [####                                    ] | 10% Completed | 163.98 sProcessed median_10540.tif
# Processed median_10540.tif
# [####                                    ] | 10% Completed | 186.00 sError processing median_1459.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [####                                    ] | 10% Completed | 192.35 sProcessed median_7431.tif
# [####                                    ] | 10% Completed | 192.46 sProcessed median_7431.tif
# [####                                    ] | 10% Completed | 192.57 sProcessed median_7431.tif
# [####                                    ] | 10% Completed | 193.43 sError processing median_8534.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [####                                    ] | 11% Completed | 197.97 sError processing median_8073.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [####                                    ] | 11% Completed | 204.62 sError processing median_5064.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [####                                    ] | 12% Completed | 215.34 sProcessed median_3761.tif
# [####                                    ] | 12% Completed | 215.45 sProcessed median_3761.tif
# [####                                    ] | 12% Completed | 215.55 sProcessed median_3761.tif
# [####                                    ] | 12% Completed | 215.65 sProcessed median_3761.tif
# [####                                    ] | 12% Completed | 215.75 sProcessed median_3761.tif
# [#####                                   ] | 12% Completed | 225.81 sError processing median_2934.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [#####                                   ] | 13% Completed | 241.15 sError processing median_1180.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [#####                                   ] | 13% Completed | 249.83 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 249.94 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 250.06 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 250.17 sProcessed median_7852.tif
# Processed median_7852.tif
# [#####                                   ] | 13% Completed | 250.28 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 250.39 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 250.49 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 250.59 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 250.69 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 250.80 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 250.90 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 251.00 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 251.10 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 251.21 sProcessed median_7852.tif
# [#####                                   ] | 13% Completed | 251.35 sProcessed median_7852.tif
# [#####                                   ] | 14% Completed | 287.72 sError processing median_5074.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [######                                  ] | 15% Completed | 290.13 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 290.24 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 290.45 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 290.67 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 290.80 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 291.06 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 291.30 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 291.43 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 291.69 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 291.82 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 292.12 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 292.26 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 292.55 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 292.67 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 293.03 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 293.25 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 293.37 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 293.79 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 293.90 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 294.05 sProcessed median_3706.tif
# [######                                  ] | 15% Completed | 305.55 sError processing median_1267.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [######                                  ] | 15% Completed | 306.87 sProcessed median_8531.tif
# [######                                  ] | 15% Completed | 307.26 sProcessed median_8531.tif
# [######                                  ] | 15% Completed | 307.59 sProcessed median_8531.tif
# [######                                  ] | 15% Completed | 308.14 sProcessed median_8531.tif
# [######                                  ] | 15% Completed | 308.27 sProcessed median_8531.tif
# [######                                  ] | 15% Completed | 308.51 sProcessed median_8531.tif
# [######                                  ] | 15% Completed | 308.77 sProcessed median_8531.tif
# [######                                  ] | 16% Completed | 311.96 sError processing median_9311.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [######                                  ] | 16% Completed | 320.41 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 320.61 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 320.84 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 320.95 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 321.28 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 321.39 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 321.68 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 321.81 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 322.04 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 322.22 sError processing median_94.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [######                                  ] | 16% Completed | 322.34 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 322.51 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 322.63 sProcessed median_8696.tif
# Processed median_8696.tif
# [######                                  ] | 16% Completed | 322.73 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 322.84 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 322.95 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 323.08 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 323.25 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 323.48 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 323.83 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 324.07 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 324.20 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 324.50 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 324.62 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 324.78 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 325.06 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 325.18 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 325.39 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 325.62 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 325.89 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 326.10 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 326.41 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 326.65 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 326.91 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 327.09 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 327.32 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 327.43 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 327.71 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 328.08 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 328.25 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 328.40 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 328.64 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 328.84 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 328.97 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 329.20 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 329.37 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 329.70 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 329.84 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 329.95 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 330.26 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 330.47 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 330.69 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 330.93 sProcessed median_8696.tif
# Processed median_8696.tif
# [######                                  ] | 16% Completed | 331.16 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 331.38 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 331.68 sProcessed median_8696.tif
# Processed median_8696.tif
# [######                                  ] | 16% Completed | 331.96 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 332.13 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 332.24 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 332.36 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 332.46 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 332.63 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 332.95 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 333.09 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 333.20 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 333.37 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 333.48 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 333.80 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 334.03 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 334.26 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 334.40 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 334.64 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 334.86 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 335.01 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 335.18 sProcessed median_8696.tif
# [######                                  ] | 16% Completed | 336.44 sProcessed median_5565.tif
# [######                                  ] | 16% Completed | 336.72 sProcessed median_5565.tif
# [######                                  ] | 16% Completed | 336.95 sProcessed median_5565.tif
# [######                                  ] | 16% Completed | 337.10 sProcessed median_5565.tif
# [######                                  ] | 17% Completed | 344.18 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 344.42 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 344.63 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 345.29 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 345.58 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 345.73 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 346.09 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 346.31 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 346.43 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 346.71 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 346.82 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 347.10 sProcessed median_10375.tif
# [######                                  ] | 17% Completed | 347.47 sProcessed median_10375.tif
# [#######                                 ] | 18% Completed | 361.98 sError processing median_4569.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [#######                                 ] | 18% Completed | 371.48 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 371.72 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 371.95 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 372.30 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 372.53 sProcessed median_4637.tif
# Processed median_4637.tif
# [#######                                 ] | 18% Completed | 372.78 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 372.97 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 373.48 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 373.82 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 374.20 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 374.53 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 374.64 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 374.89 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 374.99 sProcessed median_4637.tif
# [#######                                 ] | 18% Completed | 375.10 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 375.31 sProcessed median_1106.tif
# Processed median_4637.tif
# [#######                                 ] | 18% Completed | 375.49 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 375.68 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 375.93 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 376.06 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 376.23 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 376.46 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 376.57 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 376.80 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 376.98 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 377.11 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 377.25 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 377.37 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 377.61 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 377.74 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 378.00 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 378.24 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 378.48 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 378.59 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 378.79 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 378.96 sProcessed median_6927.tif
# [#######                                 ] | 18% Completed | 379.07 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 379.26 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 379.52 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 379.66 sProcessed median_6927.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 379.86 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 380.09 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 380.31 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 380.63 sProcessed median_1106.tif
# Processed median_574.tif
# [#######                                 ] | 18% Completed | 380.73 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 380.85 sProcessed median_574.tif
# Processed median_1106.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 381.08 sProcessed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 381.22 sProcessed median_1106.tif
# Processed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 381.45 sProcessed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 381.59 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 381.92 sProcessed median_574.tif
# [#######                                 ] | 18% Completed | 382.06 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 382.18 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 382.31 sProcessed median_574.tif
# [#######                                 ] | 18% Completed | 382.48 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 382.75 sProcessed median_1106.tif
# Processed median_574.tif
# [#######                                 ] | 18% Completed | 382.99 sProcessed median_1106.tif
# Processed median_574.tif
# [#######                                 ] | 18% Completed | 383.28 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 383.58 sProcessed median_1106.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 383.88 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 384.10 sProcessed median_1106.tif
# Processed median_574.tif
# [#######                                 ] | 18% Completed | 384.21 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 384.49 sProcessed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 384.75 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 384.91 sProcessed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 385.15 sProcessed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 385.38 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 385.57 sProcessed median_574.tif
# [#######                                 ] | 18% Completed | 385.69 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 385.97 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 386.23 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 386.44 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 386.62 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 386.98 sProcessed median_1106.tif
# Processed median_574.tif
# [#######                                 ] | 18% Completed | 387.23 sProcessed median_1106.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 387.36 sProcessed median_1106.tif
# [#######                                 ] | 18% Completed | 387.64 sProcessed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 18% Completed | 387.88 sProcessed median_1106.tif
# [#######                                 ] | 19% Completed | 388.01 sProcessed median_1106.tif
# Processed median_574.tif
# [#######                                 ] | 19% Completed | 388.29 sProcessed median_1106.tif
# Processed median_574.tif
# [#######                                 ] | 19% Completed | 388.40 sProcessed median_1106.tif
# [#######                                 ] | 19% Completed | 388.58 sProcessed median_574.tif
# [#######                                 ] | 19% Completed | 388.70 sProcessed median_1106.tif
# [#######                                 ] | 19% Completed | 388.82 sProcessed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 19% Completed | 389.20 sProcessed median_1106.tif
# Processed median_574.tif
# [#######                                 ] | 19% Completed | 389.32 sProcessed median_1106.tif
# [#######                                 ] | 19% Completed | 389.42 sProcessed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 19% Completed | 389.53 sProcessed median_1106.tif
# [#######                                 ] | 19% Completed | 389.69 sProcessed median_1106.tif
# Processed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 19% Completed | 389.81 sProcessed median_574.tif
# [#######                                 ] | 19% Completed | 389.91 sProcessed median_1106.tif
# [#######                                 ] | 19% Completed | 390.02 sProcessed median_1106.tif
# Processed median_574.tif
# Processed median_1106.tif
# [#######                                 ] | 19% Completed | 390.23 sProcessed median_1106.tif
# [#######                                 ] | 19% Completed | 390.47 sProcessed median_574.tif
# [#######                                 ] | 19% Completed | 390.71 sProcessed median_574.tif
# [########                                ] | 20% Completed | 408.56 sProcessed median_8193.tif
# [########                                ] | 20% Completed | 409.45 sProcessed median_8193.tif
# Processed median_11056.tif
# [########                                ] | 20% Completed | 409.63 sProcessed median_11056.tif
# [########                                ] | 20% Completed | 409.74 sProcessed median_8193.tif
# [########                                ] | 20% Completed | 409.84 sProcessed median_11056.tif
# [########                                ] | 20% Completed | 409.99 sProcessed median_11056.tif
# [########                                ] | 20% Completed | 410.18 sProcessed median_11056.tif
# [########                                ] | 20% Completed | 410.42 sProcessed median_11056.tif
# [########                                ] | 20% Completed | 410.52 sProcessed median_11056.tif
# [########                                ] | 20% Completed | 410.65 sProcessed median_11056.tif
# [########                                ] | 20% Completed | 410.94 sProcessed median_11056.tif
# [########                                ] | 20% Completed | 411.33 sProcessed median_1447.tif
# [########                                ] | 20% Completed | 411.54 sProcessed median_1447.tif
# Error processing median_10921.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [########                                ] | 20% Completed | 411.80 sProcessed median_1447.tif
# [########                                ] | 20% Completed | 412.03 sProcessed median_1447.tif
# [########                                ] | 20% Completed | 412.30 sProcessed median_1447.tif
# [########                                ] | 20% Completed | 412.41 sProcessed median_1447.tif
# [########                                ] | 20% Completed | 412.82 sProcessed median_1447.tif
# [########                                ] | 20% Completed | 413.06 sProcessed median_1447.tif
# ...
# [######################################  ] | 95% Completed | 30m 18sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 18sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 19sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 19sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 19sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 19sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 19sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 20sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 20sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 20sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 20sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 20sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 20sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 20sProcessed median_885.tif
# [######################################  ] | 95% Completed | 30m 20sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 21sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 21sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 21sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 21sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 21sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 21sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 21sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 21sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 22sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 22sProcessed median_10371.tif
# [######################################  ] | 96% Completed | 30m 22sProcessed median_885.tif
# Processed median_10371.tif
# [######################################  ] | 96% Completed | 30m 22sProcessed median_885.tif
# Processed median_10371.tif
# [######################################  ] | 96% Completed | 30m 22sProcessed median_10371.tif
# Processed median_885.tif
# [######################################  ] | 96% Completed | 30m 22sProcessed median_885.tif
# Processed median_10371.tif
# [######################################  ] | 96% Completed | 30m 23sProcessed median_885.tif
# Processed median_10371.tif
# [######################################  ] | 96% Completed | 30m 23sError processing median_6262.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [######################################  ] | 96% Completed | 30m 23sProcessed median_10371.tif
# [######################################  ] | 96% Completed | 30m 23sProcessed median_10371.tif
# [######################################  ] | 96% Completed | 30m 23sProcessed median_10371.tif
# Processed median_885.tif
# [######################################  ] | 96% Completed | 30m 23sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 23sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 24sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 24sProcessed median_885.tif
# Processed median_885.tif
# [######################################  ] | 96% Completed | 30m 24sProcessed median_885.tif
# Processed median_885.tif
# [######################################  ] | 96% Completed | 30m 24sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 24sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 25sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 25sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 25sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 25sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 25sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 25sProcessed median_885.tif
# Processed median_885.tif
# [######################################  ] | 96% Completed | 30m 25sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 25sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 26sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 26sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 26sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 26sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 26sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 26sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 27sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 27sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 27sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 27sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 27sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 27sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 28sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 28sProcessed median_885.tif
# Error processing median_11147.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [######################################  ] | 96% Completed | 30m 28sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 28sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 28sProcessed median_885.tif
# Processed median_885.tif
# [######################################  ] | 96% Completed | 30m 28sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 29sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 29sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 30sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 30sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 30sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 30sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 30sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 30sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 30sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 30sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 31sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 32sProcessed median_885.tif
# Processed median_885.tif
# [######################################  ] | 96% Completed | 30m 32sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 32sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 32sProcessed median_885.tif
# Processed median_5523.tif
# [######################################  ] | 96% Completed | 30m 32sProcessed median_885.tif
# Processed median_5523.tif
# [######################################  ] | 96% Completed | 30m 33sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 33sProcessed median_5523.tif
# [######################################  ] | 96% Completed | 30m 33sProcessed median_5523.tif
# [######################################  ] | 96% Completed | 30m 33sProcessed median_5523.tif
# [######################################  ] | 96% Completed | 30m 34sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 34sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 34sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 34sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 34sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 34sError processing median_10677.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# Processed median_885.tif
# [######################################  ] | 96% Completed | 30m 35sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 35sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 36sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 36sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 37sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 37sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 37sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 37sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 37sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 39sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 39sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 39sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 39sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 39sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 39sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 39sProcessed median_885.tif
# [######################################  ] | 96% Completed | 30m 39sProcessed median_885.tif
# [######################################  ] | 97% Completed | 30m 40sProcessed median_885.tif
# [######################################  ] | 97% Completed | 30m 47sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 47sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 47sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 47sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 47sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 47sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 47sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 47sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# Processed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [######################################  ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 48sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 49sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 50sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 50sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 50sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 50sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 50sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 50sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 50sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 50sProcessed median_2088.tif
# [####################################### ] | 97% Completed | 30m 52sError processing median_4795.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [####################################### ] | 98% Completed | 30m 59sError processing median_7465.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [####################################### ] | 98% Completed | 31m 5ssError processing median_3757.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# [####################################### ] | 98% Completed | 31m 19sProcessed median_2548.tif
# [####################################### ] | 98% Completed | 31m 19sProcessed median_2548.tif
# [####################################### ] | 98% Completed | 31m 19sProcessed median_2548.tif
# [####################################### ] | 98% Completed | 31m 20sProcessed median_2548.tif
# [####################################### ] | 98% Completed | 31m 20sProcessed median_2548.tif
# [####################################### ] | 98% Completed | 31m 20sProcessed median_2548.tif
# [####################################### ] | 98% Completed | 31m 20sProcessed median_2548.tif
# [####################################### ] | 98% Completed | 31m 20sProcessed median_2548.tif
# [####################################### ] | 98% Completed | 31m 21sProcessed median_2548.tif
# [####################################### ] | 99% Completed | 31m 39sProcessed median_6603.tif
# [####################################### ] | 99% Completed | 31m 39sProcessed median_6603.tif
# [####################################### ] | 99% Completed | 31m 39sProcessed median_6603.tif
# [########################################] | 100% Completed | 31m 44s

# %%
't'
# Out:
# 't'

# %% [markdown]
# Now take those files and save a csv with file names for the 80/10/10 training, validation, testing parts

# %%
def listdir_fullpath(d):
    return [os.path.join(d, f) for f in os.listdir(d)]

#list of files
# file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_1985_sent_harm_subs_128')
file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old_subs_0_128')


#shuffle file_names
file_names = shuffle(file_names, random_state = 555)


print(len(file_names))

random.seed(555)
# #get train at 80%

train_files = random.sample(file_names, k=round(len(file_names) * 0.8))

#files at 10%
val_files = list(set(file_names) - set(train_files))
val_files = random.sample(val_files, k=round(len(file_names) * 0.1))

#combine traini and val
temp = train_files + val_files
#get test files at 10%
test_files = list(set(file_names) - set(temp))


#convert the lists to pandas dataframes
train = pd.DataFrame({'Files': train_files})
val = pd.DataFrame({'Files': val_files})
test = pd.DataFrame({'Files': test_files})

print(train.shape)
print(val.shape)
print(test.shape)

train.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old_training_files.csv')
val.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old_validation_files.csv')
test.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_old_testing_files.csv')
# Out:
# 648780
# (519024, 1)
# (64878, 1)
# (64878, 1)

# %%
't'
# Out:
# 't'
