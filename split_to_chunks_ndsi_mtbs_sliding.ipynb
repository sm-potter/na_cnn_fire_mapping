# %% [markdown]
# This script will read in the tif files and split into chunks of 128x128 for training the model.  Note I will ignore all chunks where there is no data for dNBR as we wouldn't want to train on this.
# The in path and outpath have to be where the files from the tif files were sent to from the google cloud storage bucket after downloading from earth engine.

# %% [markdown]
# Read in packages

# %%
import pandas as pd
import os
import numpy as np
import xarray as xr
import rioxarray
import glob
import random
import geopandas as gpd
from sklearn.utils import shuffle
from MightyMosaic import MightyMosaic

# %% [markdown]
# Right now the files are called final_i.tif, make median_i.tif

# %%
import os
import re

# Define the input path
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_monthly_ndsi_sliding'

# List all files in the directory
files = os.listdir(in_path)

# Loop through the files
for file_name in files:
    if 'final' in file_name:
        # Extract the number i using regex
        match = re.search(r'\d+', file_name)
        if match:
            number = match.group(0)
            # Create the new file name
            new_name = f'median_{number}.tif'
            # Get the full paths
            old_file = os.path.join(in_path, file_name)
            new_file = os.path.join(in_path, new_name)
            # Rename the file
            os.rename(old_file, new_file)
            print(f'Renamed: {old_file} -> {new_file}')

# %% [markdown]
# First take the input tif files and chunk them to sizes of 128x128 for the neural network.

# %%
"""arguments are path to .tif files to be chunked, out_path to save files, chunk size, and if desired a threshold"""       

#check if all 0
def is_matrix_all_zeros(matrix):
    # Convert the matrix to a NumPy array
    np_matrix = np.array(matrix)

    # Check if all elements in the array are zeros
    return np.all(np_matrix == 0)

#in_path to tif files
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_ndsi_sliding'

#out_path which will be manipulated based on parameters below
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_ndsi_sliding'


#right now everything is set to use 0 dnbr threshold
size = 128
threshold = True

if threshold == True:

    out_path = out_path + '_subs_0_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

if threshold == False:

    out_path = out_path + '_subs_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

files = os.listdir(in_path)

# files = ['median_6169.tif']

#loop through files
for f in files:

    if f.endswith('.tif'):
        
         
        #in file
        try:
        
            #file name
            f2 = f.replace('median_', '')

            #ID of file
            f_id = int(f2.replace('.tif', ''))
        
     

            #read in file
            in_mat = rioxarray.open_rasterio(os.path.join(in_path, f))

            
            #now turn in mat to numpy, and in mtbs to numpy
            in_mat = in_mat.to_numpy().astype(float)


            #convert to band last
            in_mat = np.moveaxis(in_mat, 0, 2) 
            
               
            #get dnbr
            t = in_mat[:, :, 0]
            
             #check if all 0
            result = is_matrix_all_zeros(t)
            
            #if it is not all 0s keep data
            if result == False:

                #mosaic
                mosaic = MightyMosaic.from_array(in_mat, (size,size), overlap_factor=1) 

                #take off last dimensions of mosaic which give edge effects as they are filled with no data
                mosaic = mosaic[:-1, :-1, :, :, :]


                #first two dimensions are number of chunks, 3 and 4 are size (256, 266) and last is nbands
                for i in range(mosaic.shape[0]):

                    for j in range(mosaic.shape[1]):

                        fname = os.path.join(str(i) + '_' +  str(j)+ '_' + f2.replace('.tif', '.npy'))
                        out_name = os.path.join(out_path, fname)

                        if os.path.exists(out_name) == False:

                            in_mat3 = mosaic[i, j, :, :, :-1]

                            target = mosaic[i, j, :, :, 3]

                            #turn nan to -999
                            in_mat[np.isnan(in_mat)] = -999

                            target = target.astype('int')

                            target[target <0 ] = 0
                            target[target >1 ] = 0

                            #
                            target[~np.isin(target, [0,1])] = 0

                            #turn nan to 0
                            target[np.isnan(target)] = 0

                            #if the target is all 0 don't train on it
                            # if np.all(target == 0) == False:

                            #now get dnbr which is the 6th band
                            dnbr = in_mat3[:, :, 0]
                            
                            result1 = is_matrix_all_zeros(dnbr)

                            if result1 == False:

                                #if threshold apply dnbr threshold
                                target[dnbr < 0] = 0

                                e = np.dstack([in_mat3, target])

                                np.save(out_name, e)

                                print(f)

        except:
            pass

# %% [markdown]
# Faster with dask

# %%
import os
import numpy as np
import rioxarray
import dask
from dask.diagnostics import ProgressBar
from MightyMosaic import MightyMosaic

# Check if all elements in a matrix are zero
def is_matrix_all_zeros(matrix):
    np_matrix = np.array(matrix)
    return np.all(np_matrix == 0)

# Input and output paths
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_monthly_ndsi_sliding'
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_monthly_ndsi_sliding'
size = 128
threshold = True

# Set output path based on threshold
if threshold:
    out_path += f'_subs_0_{size}'
else:
    out_path += f'_subs_{size}'

if not os.path.isdir(out_path):
    os.makedirs(out_path)

files = [f for f in os.listdir(in_path) if f.endswith('.tif')]

# Define the function to process a single file
def process_file(f):
    try:
        f2 = f.replace('median_', '')
        f_id = int(f2.replace('.tif', ''))
        in_mat = rioxarray.open_rasterio(os.path.join(in_path, f)).to_numpy().astype(float)
        in_mat = np.moveaxis(in_mat, 0, 2) 
        t = in_mat[:, :, 0]
        if not is_matrix_all_zeros(t):
            mosaic = MightyMosaic.from_array(in_mat, (size, size), overlap_factor=1) 
            mosaic = mosaic[:-1, :-1, :, :, :]
            for i in range(mosaic.shape[0]):
                for j in range(mosaic.shape[1]):
                    fname = os.path.join(str(i) + '_' +  str(j) + '_' + f2.replace('.tif', '.npy'))
                    out_name = os.path.join(out_path, fname)
                    if not os.path.exists(out_name):
                        in_mat3 = mosaic[i, j, :, :, :-1]
                        target = mosaic[i, j, :, :, 3]
                        in_mat3[np.isnan(in_mat3)] = -999
                        target = target.astype('int')
                        target[target < 0] = 0
                        target[target > 1] = 0
                        target[~np.isin(target, [0, 1])] = 0
                        target[np.isnan(target)] = 0
                        dnbr = in_mat3[:, :, 0]
                        if not is_matrix_all_zeros(dnbr):
                            if threshold:
                                target[dnbr < 0] = 0
                            e = np.dstack([in_mat3, target])
                            np.save(out_name, e)
                            print(f"Processed {f}")
    except Exception as e:
        print(f"Error processing {f}: {e}")

# Parallel execution using Dask
tasks = [dask.delayed(process_file)(f) for f in files]

with ProgressBar():
    dask.compute(*tasks)
# Out:
# [                                        ] | 0% Completed | 425.14 msProcessed median_475.tif
# Processed median_618.tif
# [                                        ] | 0% Completed | 532.45 msProcessed median_475.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_618.tif
# Processed median_618.tif
# [                                        ] | 0% Completed | 633.39 msProcessed median_618.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 735.97 msProcessed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# [                                        ] | 0% Completed | 837.96 msProcessed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_618.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 954.33 msProcessed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# Processed median_618.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 1.07 sProcessed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 1.18 sProcessed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 1.28 sProcessed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 1.40 sProcessed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# [                                        ] | 0% Completed | 1.51 sProcessed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# [                                        ] | 0% Completed | 1.63 sProcessed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 1.74 sProcessed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 1.85 sProcessed median_584.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 1.97 sProcessed median_475.tif
# Processed median_584.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_584.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_584.tif
# [                                        ] | 0% Completed | 2.07 sProcessed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 2.17 sProcessed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# [                                        ] | 0% Completed | 2.27 sProcessed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_1100.tif
# [                                        ] | 0% Completed | 2.40 sProcessed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 2.52 sProcessed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 2.62 sProcessed median_1100.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# [                                        ] | 0% Completed | 2.73 sProcessed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# Processed median_1100.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 2.83 sProcessed median_475.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 2.93 sProcessed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 3.05 sProcessed median_1105.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_1105.tif
# [                                        ] | 0% Completed | 3.15 sProcessed median_475.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 3.27 sProcessed median_1105.tif
# Processed median_1105.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 3.37 sProcessed median_1105.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_475.tif
# [                                        ] | 0% Completed | 3.47 sProcessed median_1105.tif
# Processed median_475.tif
# Processed median_475.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_1105.tif
# [                                        ] | 0% Completed | 3.57 sProcessed median_1105.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_1105.tif
# [                                        ] | 0% Completed | 3.68 sProcessed median_1105.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# [                                        ] | 0% Completed | 3.78 sProcessed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# [                                        ] | 0% Completed | 3.88 sProcessed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# [                                        ] | 0% Completed | 4.00 sProcessed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_336.tif
# [                                        ] | 0% Completed | 4.12 sProcessed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# [                                        ] | 0% Completed | 4.23 sProcessed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_336.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_336.tif
# [                                        ] | 0% Completed | 4.33 sProcessed median_336.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_336.tif
# Processed median_1105.tif
# [                                        ] | 0% Completed | 4.45 sProcessed median_336.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# [                                        ] | 0% Completed | 4.55 sProcessed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# Processed median_336.tif
# Processed median_1105.tif
# [                                        ] | 0% Completed | 4.65 sProcessed median_1105.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_1105.tif
# Processed median_107.tif
# Processed median_107.tif
# [                                        ] | 0% Completed | 4.98 sProcessed median_1033.tif
# Processed median_1033.tif
# [                                        ] | 0% Completed | 5.10 sProcessed median_1033.tif
# Processed median_1033.tif
# Processed median_1033.tif
# Processed median_1033.tif
# Processed median_1033.tif
# [                                        ] | 0% Completed | 5.23 sProcessed median_1033.tif
# Processed median_1033.tif
# Processed median_1033.tif
# Processed median_1033.tif
# Processed median_1033.tif
# [                                        ] | 0% Completed | 5.35 sProcessed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 5.45 sProcessed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_1033.tif
# [                                        ] | 0% Completed | 5.56 sProcessed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# [                                        ] | 0% Completed | 5.67 sProcessed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# [                                        ] | 0% Completed | 5.78 sProcessed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 5.90 sProcessed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# [                                        ] | 0% Completed | 6.00 sProcessed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# [                                        ] | 0% Completed | 6.12 sProcessed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# Processed median_1033.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 6.23 sProcessed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 6.33 sProcessed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 6.44 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 6.56 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_862.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 6.67 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 6.79 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 6.94 sProcessed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 7.05 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 7.15 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 7.26 sProcessed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 7.37 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 7.47 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_862.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 7.57 sProcessed median_862.tif
# Processed median_862.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 7.68 sProcessed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 7.78 sProcessed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 7.88 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 7.99 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 8.11 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# [                                        ] | 0% Completed | 8.23 sProcessed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_862.tif
# Processed median_809.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 8.33 sProcessed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 8.47 sProcessed median_1027.tif
# Processed median_809.tifProcessed median_1027.tif
#
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 8.57 sProcessed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 8.67 sProcessed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 8.77 sProcessed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 8.89 sProcessed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# [                                        ] | 0% Completed | 9.01 sProcessed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# [                                        ] | 0% Completed | 9.11 sProcessed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 9.22 sProcessed median_809.tif
# Processed median_1027.tif
# Processed median_1027.tif
# Processed median_1027.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 9.33 sProcessed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_1027.tif
# [                                        ] | 0% Completed | 9.44 sProcessed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# [                                        ] | 0% Completed | 9.56 sProcessed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 9.66 sProcessed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 9.78 sProcessed median_1027.tif
# Processed median_1027.tif
# Processed median_809.tif
# Processed median_1027.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 9.88 sProcessed median_1027.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# [                                        ] | 0% Completed | 9.99 sProcessed median_809.tif
# Processed median_809.tif
# Processed median_809.tif
# [                                        ] | 1% Completed | 10.57 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 10.67 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 10.79 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 10.90 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 11.01 sProcessed median_504.tif
# [                                        ] | 1% Completed | 11.12 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 11.25 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 11.35 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 11.46 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 11.56 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 11.66 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 11.77 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 11.87 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 11.98 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 12.15 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 12.25 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 12.37 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 12.47 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 12.59 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 12.69 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tifProcessed median_504.tif
#
# [                                        ] | 1% Completed | 12.82 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 12.92 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 13.07 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 13.17 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 13.28 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 13.38 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 13.48 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 13.59 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 13.70 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 13.80 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 13.91 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 14.02 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 14.12 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 14.23 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 14.37 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 14.49 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 14.63 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 14.74 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 14.85 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 14.96 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 15.06 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 15.16 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 15.26 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 15.38 sProcessed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 15.48 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 15.59 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 15.69 sProcessed median_1167.tif
# Processed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tifProcessed median_1167.tif
#
# Processed median_504.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 15.80 sProcessed median_504.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# Processed median_1167.tif
# Processed median_504.tif
# [                                        ] | 1% Completed | 15.91 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 16.01 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 16.12 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 16.22 sProcessed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 16.33 sProcessed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 16.44 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 16.54 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 16.65 sProcessed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 16.75 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 16.85 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 16.95 sProcessed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 17.06 sProcessed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 17.16 sProcessed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 17.28 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 17.38 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 17.49 sProcessed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 17.60 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 17.71 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 17.81 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 17.91 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 18.07 sProcessed median_1167.tif
# Processed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 18.18 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 18.30 sProcessed median_531.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# Processed median_1167.tif
# Processed median_531.tif
# [                                        ] | 1% Completed | 18.42 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 18.53 sProcessed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# [                                        ] | 1% Completed | 18.64 sProcessed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# [                                        ] | 1% Completed | 18.75 sProcessed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 18.85 sProcessed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_937.tif
# Processed median_937.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 18.96 sProcessed median_1167.tif
# Processed median_1167.tif
# Processed median_200.tif
# [                                        ] | 1% Completed | 19.06 sProcessed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# [                                        ] | 1% Completed | 19.17 sProcessed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# [                                        ] | 1% Completed | 19.28 sProcessed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 19.40 sProcessed median_1167.tifProcessed median_200.tif
#
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# [                                        ] | 1% Completed | 19.51 sProcessed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# [                                        ] | 1% Completed | 19.63 sProcessed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_1167.tif
# Processed median_200.tif
# Processed median_200.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 19.73 sProcessed median_200.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1167.tif
# Processed median_1113.tif
# [                                        ] | 1% Completed | 19.84 sProcessed median_1167.tif
# Processed median_1113.tif
# Processed median_1167.tif
# Processed median_1113.tif
# Processed median_1167.tif
# Processed median_1113.tif
# Processed median_1167.tif
# Processed median_1113.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 19.94 sProcessed median_1113.tif
# Processed median_1167.tif
# Processed median_1113.tif
# Processed median_1167.tif
# Processed median_1113.tif
# Processed median_1167.tif
# [                                        ] | 1% Completed | 20.04 sProcessed median_1113.tif
# Processed median_1167.tif
# Processed median_1113.tif
# Processed median_1167.tif
# Processed median_1113.tif
# [                                        ] | 1% Completed | 20.15 sProcessed median_1113.tif
# Processed median_1113.tif
# Processed median_1113.tif
# [                                        ] | 1% Completed | 20.26 sProcessed median_1113.tif
# Processed median_1081.tif
# Processed median_1081.tif
# Processed median_1113.tif
# [                                        ] | 1% Completed | 20.37 sProcessed median_1081.tif
# Error processing median_354.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# Processed median_1081.tif
# Processed median_1081.tif
# Processed median_1081.tif
# [                                        ] | 1% Completed | 20.47 sProcessed median_1081.tif
# Processed median_1081.tif
# [                                        ] | 1% Completed | 20.57 sProcessed median_1081.tif
# Processed median_1081.tif
# Processed median_1081.tif
# Processed median_1081.tif
# [                                        ] | 1% Completed | 20.69 sProcessed median_1081.tif
# Processed median_1081.tif
# Processed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 20.79 sProcessed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 20.91 sProcessed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_607.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_1081.tif
# [                                        ] | 1% Completed | 21.01 sProcessed median_1081.tif
# Processed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 21.11 sProcessed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 21.21 sProcessed median_1081.tif
# Processed median_607.tif
# Processed median_1081.tif
# Processed median_607.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 21.33 sProcessed median_607.tif
# Processed median_607.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 21.43 sProcessed median_607.tif
# Processed median_607.tif
# Processed median_607.tif
# Processed median_607.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 21.54 sProcessed median_607.tif
# Processed median_607.tif
# Processed median_523.tif
# Processed median_607.tif
# Processed median_523.tif
# Processed median_607.tif
# Processed median_523.tif
# [                                        ] | 1% Completed | 21.66 sProcessed median_607.tif
# Processed median_523.tif
# Processed median_523.tif
# Processed median_607.tif
# Processed median_523.tif
# Processed median_607.tif
# Processed median_523.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 21.76 sProcessed median_523.tif
# Processed median_607.tif
# Processed median_523.tif
# Processed median_523.tif
# Processed median_607.tif
# Processed median_523.tif
# [                                        ] | 1% Completed | 21.88 sProcessed median_607.tif
# Processed median_523.tif
# Processed median_523.tif
# Processed median_523.tif
# Processed median_523.tif
# Processed median_607.tif
# [                                        ] | 1% Completed | 22.00 sProcessed median_523.tif
# Processed median_523.tif
# Processed median_607.tif
# ...
# Processed median_751.tif
# [####                                    ] | 11% Completed | 109.31 sProcessed median_522.tif
# Processed median_751.tif
# Processed median_522.tif
# Processed median_751.tif
# Processed median_522.tif
# [####                                    ] | 11% Completed | 109.41 sProcessed median_751.tif
# Processed median_522.tif
# Processed median_751.tif
# Processed median_522.tif
# Processed median_751.tif
# Processed median_751.tif
# Processed median_522.tif
# [####                                    ] | 11% Completed | 109.51 sProcessed median_751.tif
# Processed median_751.tif
# Processed median_522.tif
# Processed median_522.tif
# Processed median_751.tif
# [####                                    ] | 11% Completed | 109.62 sProcessed median_522.tif
# Processed median_751.tif
# Processed median_751.tif
# Processed median_522.tif
# Processed median_751.tif
# Processed median_522.tif
# Processed median_522.tif
# [####                                    ] | 11% Completed | 109.76 sProcessed median_751.tif
# Processed median_751.tif
# Processed median_751.tif
# Processed median_751.tif
# [####                                    ] | 11% Completed | 109.86 sProcessed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# [####                                    ] | 11% Completed | 109.96 sProcessed median_662.tif
# Processed median_751.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# [####                                    ] | 11% Completed | 110.08 sProcessed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# [####                                    ] | 11% Completed | 110.19 sProcessed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_751.tif
# [####                                    ] | 11% Completed | 110.31 sProcessed median_662.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# Processed median_662.tif
# Processed median_751.tif
# [####                                    ] | 12% Completed | 110.41 sProcessed median_751.tif
# Processed median_751.tif
# Processed median_751.tif
# Processed median_751.tif
# [####                                    ] | 12% Completed | 111.05 sProcessed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 111.15 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 111.25 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 111.38 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 111.48 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 111.59 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 111.69 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 111.79 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 111.89 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 112.01 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 112.12 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 112.22 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 112.32 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 112.42 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 112.53 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 112.66 sProcessed median_82.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 112.76 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 112.86 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 112.96 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 113.07 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 113.17 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 113.28 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 113.41 sProcessed median_82.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 113.52 sProcessed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_82.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_82.tif
# [####                                    ] | 12% Completed | 113.63 sProcessed median_82.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 113.73 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_291.tif
# [####                                    ] | 12% Completed | 113.84 sProcessed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_291.tif
# Processed median_291.tif
# [####                                    ] | 12% Completed | 113.94 sProcessed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_291.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 114.05 sProcessed median_291.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_291.tif
# [####                                    ] | 12% Completed | 114.17 sProcessed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 114.27 sProcessed median_314.tif
# Processed median_291.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 114.38 sProcessed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 114.48 sProcessed median_314.tif
# Processed median_291.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_291.tif
# [####                                    ] | 12% Completed | 114.59 sProcessed median_314.tif
# Processed median_859.tif
# [####                                    ] | 12% Completed | 114.70 sProcessed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 114.81 sProcessed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 114.91 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# [####                                    ] | 12% Completed | 115.03 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.14 sProcessed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.24 sProcessed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.35 sProcessed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# Processed median_859.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.45 sProcessed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.55 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.69 sProcessed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.79 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.89 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 115.99 sProcessed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 116.10 sProcessed median_841.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_841.tif
# [####                                    ] | 12% Completed | 116.21 sProcessed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# [####                                    ] | 12% Completed | 116.31 sProcessed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_841.tif
# [####                                    ] | 12% Completed | 116.43 sProcessed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_841.tif
# [####                                    ] | 12% Completed | 116.53 sProcessed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# [####                                    ] | 12% Completed | 116.64 sProcessed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 116.76 sProcessed median_314.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 116.88 sProcessed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 116.98 sProcessed median_841.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_841.tif
# [####                                    ] | 12% Completed | 117.08 sProcessed median_314.tif
# Processed median_841.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 117.22 sProcessed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 117.32 sProcessed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_314.tif
# Processed median_841.tif
# [####                                    ] | 12% Completed | 117.43 sProcessed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# [####                                    ] | 12% Completed | 117.54 sProcessed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_314.tif
# [####                                    ] | 12% Completed | 117.65 sProcessed median_841.tif
# Processed median_314.tif
# Processed median_841.tif
# Processed median_841.tif
# Processed median_314.tif
# Processed median_841.tif

# %%
't'
# Out:
# 't'

# %% [markdown]
# Now take those files and save a csv with file names for the 80/10/10 training, validation, testing parts

# %%
def listdir_fullpath(d):
    return [os.path.join(d, f) for f in os.listdir(d)]

#list of files
# file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_1985_sent_harm_subs_128')
file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_monthly_ndsi_sliding_subs_0_128')


#shuffle file_names
file_names = shuffle(file_names, random_state = 555)


print(len(file_names))

random.seed(555)
# #get train at 80%

train_files = random.sample(file_names, k=round(len(file_names) * 0.8))

#files at 10%
val_files = list(set(file_names) - set(train_files))
val_files = random.sample(val_files, k=round(len(file_names) * 0.1))

#combine traini and val
temp = train_files + val_files
#get test files at 10%
test_files = list(set(file_names) - set(temp))


#convert the lists to pandas dataframes
train = pd.DataFrame({'Files': train_files})
val = pd.DataFrame({'Files': val_files})
test = pd.DataFrame({'Files': test_files})

print(train.shape)
print(val.shape)
print(test.shape)

train.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_monthly_ndsi_sliding_training_files.csv')
val.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_monthly_ndsi_sliding_validation_files.csv')
test.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_monthly_ndsi_sliding_testing_files.csv')
# Out:
# 60664
# (48531, 1)
# (6066, 1)
# (6067, 1)
