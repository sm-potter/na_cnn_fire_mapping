# %% [markdown]
# This script will read in the tif files and split into chunks of 128x128 for training the model.  Note I will ignore all chunks where there is no data for dNBR as we wouldn't want to train on this.
# The in path and outpath have to be where the files from the tif files were sent to from the google cloud storage bucket after downloading from earth engine.

# %% [markdown]
# Read in packages

# %%
import pandas as pd
import os
import numpy as np
import xarray as xr
import rioxarray
import glob
import random
import geopandas as gpd
from sklearn.utils import shuffle
from MightyMosaic import MightyMosaic

# %% [markdown]
# Right now the files are called final_i.tif, make median_i.tif

# %%
import os
import re

# Define the input path
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/mtbs_monthly_ndsi_sliding'

# List all files in the directory
files = os.listdir(in_path)

# Loop through the files
for file_name in files:
    if 'final' in file_name:
        # Extract the number i using regex
        match = re.search(r'\d+', file_name)
        if match:
            number = match.group(0)
            # Create the new file name
            new_name = f'median_{number}.tif'
            # Get the full paths
            old_file = os.path.join(in_path, file_name)
            new_file = os.path.join(in_path, new_name)
            # Rename the file
            os.rename(old_file, new_file)
            print(f'Renamed: {old_file} -> {new_file}')

# %% [markdown]
# First take the input tif files and chunk them to sizes of 128x128 for the neural network.

# %%
"""arguments are path to .tif files to be chunked, out_path to save files, chunk size, and if desired a threshold"""       

#check if all 0
def is_matrix_all_zeros(matrix):
    # Convert the matrix to a NumPy array
    np_matrix = np.array(matrix)

    # Check if all elements in the array are zeros
    return np.all(np_matrix == 0)

#in_path to tif files
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_ndsi_sliding'

#out_path which will be manipulated based on parameters below
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_ndsi_sliding'


#right now everything is set to use 0 dnbr threshold
size = 128
threshold = True

if threshold == True:

    out_path = out_path + '_subs_0_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

if threshold == False:

    out_path = out_path + '_subs_' + str(size)
    if not os.path.isdir(out_path):
        os.makedirs(out_path)

files = os.listdir(in_path)

# files = ['median_6169.tif']

#loop through files
for f in files:

    if f.endswith('.tif'):
        
         
        #in file
        try:
        
            #file name
            f2 = f.replace('median_', '')

            #ID of file
            f_id = int(f2.replace('.tif', ''))
        
     

            #read in file
            in_mat = rioxarray.open_rasterio(os.path.join(in_path, f))

            
            #now turn in mat to numpy, and in mtbs to numpy
            in_mat = in_mat.to_numpy().astype(float)


            #convert to band last
            in_mat = np.moveaxis(in_mat, 0, 2) 
            
               
            #get dnbr
            t = in_mat[:, :, 0]
            
             #check if all 0
            result = is_matrix_all_zeros(t)
            
            #if it is not all 0s keep data
            if result == False:

                #mosaic
                mosaic = MightyMosaic.from_array(in_mat, (size,size), overlap_factor=1) 

                #take off last dimensions of mosaic which give edge effects as they are filled with no data
                mosaic = mosaic[:-1, :-1, :, :, :]


                #first two dimensions are number of chunks, 3 and 4 are size (256, 266) and last is nbands
                for i in range(mosaic.shape[0]):

                    for j in range(mosaic.shape[1]):

                        fname = os.path.join(str(i) + '_' +  str(j)+ '_' + f2.replace('.tif', '.npy'))
                        out_name = os.path.join(out_path, fname)

                        if os.path.exists(out_name) == False:

                            in_mat3 = mosaic[i, j, :, :, :-1]

                            target = mosaic[i, j, :, :, 3]

                            #turn nan to -999
                            in_mat[np.isnan(in_mat)] = -999

                            target = target.astype('int')

                            target[target <0 ] = 0
                            target[target >1 ] = 0

                            #
                            target[~np.isin(target, [0,1])] = 0

                            #turn nan to 0
                            target[np.isnan(target)] = 0

                            #if the target is all 0 don't train on it
                            # if np.all(target == 0) == False:

                            #now get dnbr which is the 6th band
                            dnbr = in_mat3[:, :, 0]
                            
                            result1 = is_matrix_all_zeros(dnbr)

                            if result1 == False:

                                #if threshold apply dnbr threshold
                                target[dnbr < 0] = 0

                                e = np.dstack([in_mat3, target])

                                np.save(out_name, e)

                                print(f)

        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 34
#      31     if not os.path.isdir(out_path):
#      32         os.makedirs(out_path)
# ---> 34 files = os.listdir(in_path)
#      36 # files = ['median_6169.tif']
#      37
#      38 #loop through files
#      39 for f in files:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_ndsi_sliding'

# %% [markdown]
# Faster with dask

# %%
import os
import numpy as np
import rioxarray
import dask
from dask.diagnostics import ProgressBar
from MightyMosaic import MightyMosaic

# Check if all elements in a matrix are zero
def is_matrix_all_zeros(matrix):
    np_matrix = np.array(matrix)
    return np.all(np_matrix == 0)

# Input and output paths
in_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_monthly_ndsi_sliding'
out_path = '/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_monthly_ndsi_sliding'
size = 128
threshold = True

# Set output path based on threshold
if threshold:
    out_path += f'_subs_0_{size}'
else:
    out_path += f'_subs_{size}'

if not os.path.isdir(out_path):
    os.makedirs(out_path)

files = [f for f in os.listdir(in_path) if f.endswith('.tif')]

# Define the function to process a single file
def process_file(f):
    try:
        f2 = f.replace('median_', '')
        f_id = int(f2.replace('.tif', ''))
        in_mat = rioxarray.open_rasterio(os.path.join(in_path, f)).to_numpy().astype(float)
        in_mat = np.moveaxis(in_mat, 0, 2) 
        t = in_mat[:, :, 0]
        if not is_matrix_all_zeros(t):
            mosaic = MightyMosaic.from_array(in_mat, (size, size), overlap_factor=1) 
            mosaic = mosaic[:-1, :-1, :, :, :]
            for i in range(mosaic.shape[0]):
                for j in range(mosaic.shape[1]):
                    fname = os.path.join(str(i) + '_' +  str(j) + '_' + f2.replace('.tif', '.npy'))
                    out_name = os.path.join(out_path, fname)
                    if not os.path.exists(out_name):
                        in_mat3 = mosaic[i, j, :, :, :-1]
                        target = mosaic[i, j, :, :, 3]
                        in_mat3[np.isnan(in_mat3)] = -999
                        target = target.astype('int')
                        target[target < 0] = 0
                        target[target > 1] = 0
                        target[~np.isin(target, [0, 1])] = 0
                        target[np.isnan(target)] = 0
                        dnbr = in_mat3[:, :, 0]
                        if not is_matrix_all_zeros(dnbr):
                            if threshold:
                                target[dnbr < 0] = 0
                            e = np.dstack([in_mat3, target])
                            np.save(out_name, e)
                            print(f"Processed {f}")
    except Exception as e:
        print(f"Error processing {f}: {e}")

# Parallel execution using Dask
tasks = [dask.delayed(process_file)(f) for f in files]

with ProgressBar():
    dask.compute(*tasks)
# Out:
# [                                        ] | 0% Completed | 4.03 s msProcessed median_5972.tif
# Processed median_2343.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_4912.tif
# [                                        ] | 0% Completed | 5.32 sProcessed median_2343.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_2343.tif
# Processed median_4912.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_2343.tif
# [                                        ] | 0% Completed | 5.44 sProcessed median_100.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_8707.tif
# [                                        ] | 0% Completed | 5.57 sProcessed median_100.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_100.tif
# [                                        ] | 0% Completed | 5.68 sProcessed median_8707.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_100.tif
# [                                        ] | 0% Completed | 5.78 sProcessed median_8707.tif
# Processed median_100.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_100.tif
# [                                        ] | 0% Completed | 5.88 sProcessed median_8707.tif
# Processed median_100.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_100.tif
# [                                        ] | 0% Completed | 5.99 sProcessed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# [                                        ] | 0% Completed | 6.10 sProcessed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# [                                        ] | 0% Completed | 6.20 sProcessed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# [                                        ] | 0% Completed | 6.30 sProcessed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# Processed median_8707.tif
# [                                        ] | 0% Completed | 10.20 sProcessed median_982.tif
# Processed median_982.tif
# [                                        ] | 0% Completed | 10.30 sProcessed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# [                                        ] | 0% Completed | 10.41 sProcessed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# [                                        ] | 0% Completed | 10.61 sProcessed median_982.tif
# [                                        ] | 0% Completed | 10.71 sProcessed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# [                                        ] | 0% Completed | 10.81 sProcessed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# [                                        ] | 0% Completed | 10.91 sProcessed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# [                                        ] | 0% Completed | 11.01 sProcessed median_982.tif
# Processed median_982.tif
# Processed median_982.tif
# [                                        ] | 0% Completed | 11.42 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 11.52 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 11.62 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 11.72 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 11.82 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 11.92 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 12.02 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 12.13 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 12.23 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# Processed median_2074.tif
# [                                        ] | 0% Completed | 12.33 sProcessed median_2074.tif
# Processed median_2074.tif
# Processed median_4087.tif
# Processed median_2074.tif
# Processed median_4087.tif
# Processed median_2074.tif
# Processed median_4087.tif
# Processed median_2074.tif
# Processed median_4087.tif
# Processed median_2074.tif
# Processed median_4087.tif
# Processed median_4087.tif
# [                                        ] | 0% Completed | 12.43 sProcessed median_2074.tif
# Processed median_4087.tif
# Processed median_2074.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# [                                        ] | 0% Completed | 12.54 sProcessed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# [                                        ] | 0% Completed | 12.64 sProcessed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Error processing median_2934.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# Processed median_4087.tif
# [                                        ] | 0% Completed | 12.74 sProcessed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# [                                        ] | 0% Completed | 12.84 sProcessed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# [                                        ] | 0% Completed | 12.95 sProcessed median_4087.tif
# Processed median_4087.tif
# Processed median_4087.tif
# [                                        ] | 1% Completed | 14.81 sProcessed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# [                                        ] | 1% Completed | 14.91 sProcessed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# [                                        ] | 1% Completed | 15.01 sProcessed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# Processed median_2803.tif
# [                                        ] | 1% Completed | 15.15 sProcessed median_2803.tif
# [                                        ] | 1% Completed | 15.76 sError processing median_2724.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [                                        ] | 1% Completed | 16.06 sProcessed median_7219.tif
# Processed median_7219.tif
# Processed median_7219.tif
# Processed median_7219.tif
# Processed median_7219.tif
# Processed median_7219.tif
# Processed median_7219.tif
# [                                        ] | 1% Completed | 16.16 sProcessed median_7219.tif
# Processed median_7219.tif
# [                                        ] | 1% Completed | 16.57 sProcessed median_553.tif
# Processed median_553.tif
# [                                        ] | 1% Completed | 16.67 sProcessed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# [                                        ] | 1% Completed | 16.77 sProcessed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Error processing median_8780.tif: j_begin (0) should be less than j_end (0) (0 < 0 is False)
# Processed median_553.tif
# Processed median_553.tif
# [                                        ] | 1% Completed | 16.87 sProcessed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# [                                        ] | 1% Completed | 16.97 sProcessed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# Processed median_553.tif
# [                                        ] | 1% Completed | 18.74 sProcessed median_3828.tif
# Processed median_3828.tif
# Processed median_3828.tif
# Processed median_3828.tif
# Processed median_3828.tif
# Processed median_3828.tif
# [                                        ] | 1% Completed | 18.84 sProcessed median_3828.tif
# Processed median_3828.tif
# Processed median_3828.tif
# Processed median_3828.tif
# Processed median_3828.tif
# Processed median_3828.tif
# Processed median_6551.tif
# [                                        ] | 1% Completed | 18.95 sProcessed median_6581.tif
#
# Processed median_3828.tif
# Processed median_6581.tif
# Processed median_6551.tif
# Processed median_3828.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_6551.tif
# Processed median_3828.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_8343.tif
# Processed median_6551.tif
# Processed median_3828.tif
# Processed median_8343.tifProcessed median_6581.tif
#
# Processed median_6551.tif
# Processed median_8343.tif
# [                                        ] | 1% Completed | 19.07 sProcessed median_6581.tif
# Processed median_6551.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_6551.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_8343.tif
# Processed median_6551.tif
# Processed median_6581.tif
# Processed median_8343.tif
# Processed median_6551.tif
# [                                        ] | 1% Completed | 19.17 sProcessed median_6581.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_6551.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_6551.tif
# Processed median_8343.tif
# Processed median_6581.tif
# [                                        ] | 1% Completed | 19.27 sProcessed median_6551.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_6551.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_6551.tif
# Processed median_8343.tif
# Processed median_6581.tif
# Processed median_6551.tif
# Processed median_8343.tif
# Processed median_8343.tif
# Processed median_8343.tif
# [                                        ] | 1% Completed | 19.37 sProcessed median_8343.tif
# Processed median_8343.tif
# Processed median_8343.tif
# Processed median_8343.tif
# Processed median_8469.tif
# Processed median_8343.tif
# Processed median_8469.tif
# Processed median_8343.tif
# Processed median_8469.tif
# [                                        ] | 1% Completed |
# Processed median_7486.tif
# [####################################### ] | 97% Completed | 41m 43sError processing median_7465.tif: i_begin (0) should be less than i_end (0) (0 < 0 is False)
# [####################################### ] | 97% Completed | 41m 43sProcessed median_8158.tif
# [####################################### ] | 97% Completed | 41m 43sProcessed median_3161.tif
# Processed median_5305.tif
# Processed median_8087.tif
# Processed median_6774.tif
# Processed median_7486.tif
# Processed median_5015.tif
# Processed median_6788.tif
# [####################################### ] | 97% Completed | 41m 44sProcessed median_8158.tif
# Processed median_8607.tif
# [####################################### ] | 97% Completed | 41m 44sProcessed median_3161.tif
# Processed median_6774.tif
# Processed median_8087.tif
# Processed median_5305.tif
# Processed median_7486.tif
# [####################################### ] | 97% Completed | 41m 44sProcessed median_5015.tif
# Processed median_6788.tif
# [####################################### ] | 97% Completed | 41m 44sProcessed median_8158.tif
# Processed median_8607.tif
# Processed median_3161.tifProcessed median_8087.tif
#
# Processed median_7486.tif
# Processed median_5305.tif
# [####################################### ] | 97% Completed | 41m 44sProcessed median_8158.tif
# Processed median_6774.tif
# Processed median_5015.tif
# [####################################### ] | 97% Completed | 41m 45sProcessed median_8607.tif
# [####################################### ] | 97% Completed | 41m 45sProcessed median_8499.tif
# Processed median_8087.tif
# Processed median_7486.tif
# Processed median_5305.tif
# Processed median_3161.tif
# [####################################### ] | 98% Completed | 41m 45sProcessed median_8158.tif
# [####################################### ] | 98% Completed | 41m 45sProcessed median_6774.tif
# Processed median_5015.tif
# [####################################### ] | 98% Completed | 41m 46sProcessed median_8607.tif
# [####################################### ] | 98% Completed | 41m 46sProcessed median_8499.tif
# Processed median_3161.tifProcessed median_7486.tif
# Processed median_5305.tif
# Processed median_10077.tif
#
# Processed median_8087.tif
# [####################################### ] | 98% Completed | 41m 46s

# %%
't'
# Out:
# 't'

# %% [markdown]
# Now take those files and save a csv with file names for the 80/10/10 training, validation, testing parts

# %%
def listdir_fullpath(d):
    return [os.path.join(d, f) for f in os.listdir(d)]

#list of files
# file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_1985_sent_harm_subs_128')
file_names = listdir_fullpath('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_monthly_ndsi_sliding_subs_0_128')


#shuffle file_names
file_names = shuffle(file_names, random_state = 555)


print(len(file_names))

random.seed(555)
# #get train at 80%

train_files = random.sample(file_names, k=round(len(file_names) * 0.8))

#files at 10%
val_files = list(set(file_names) - set(train_files))
val_files = random.sample(val_files, k=round(len(file_names) * 0.1))

#combine traini and val
temp = train_files + val_files
#get test files at 10%
test_files = list(set(file_names) - set(temp))


#convert the lists to pandas dataframes
train = pd.DataFrame({'Files': train_files})
val = pd.DataFrame({'Files': val_files})
test = pd.DataFrame({'Files': test_files})

print(train.shape)
print(val.shape)
print(test.shape)

train.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_monthly_ndsi_sliding_training_files.csv')
val.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_monthly_ndsi_sliding_validation_files.csv')
test.to_csv('/explore/nobackup/people/spotter5/cnn_mapping/nbac_training/nbac_monthly_ndsi_sliding_testing_files.csv')
# Out:
# 647098
# (517678, 1)
# (64710, 1)
# (64710, 1)
